# %% [markdown]
# # Purpose
#
# The purpose of this notebook is to document my full application of the Stacks pipeline on my cod data. I've been writing scripts to work on a subset of my files, and now I want to start running them on all of my files.
#
# ## ``process_radtags``
#
# I don't have to run this on my data because the previous user of the data already did. In my script for running ``process_radtags``, however, I also use this opportunity to make folders for the output of each of the Stacks programs. So I'm doing that manually here. Below, you can see these directories plus two folders of cod data (two lanes of data):
#
# ![image](https://github.com/nclowell/FISH546/blob/master/Cod-Time-Series-Project/Notebooks/images_for_notebooks/Screen%20Shot%202016-11-16%20at%203.10.45%20PM.png?raw=true)
#
# ## ``ustacks``
#
# I'll be working off of my hard drive, so first I had to change directory to there.

# %%
cd /Volumes/Time\ Machine\ Backups/Cod-Time-Series-Data/
# Out:
# /Volumes/Time Machine Backups/Cod-Time-Series-Data

# %% [markdown]
# Another issue is that I have two lanes. It'd be easiest if I could work in only one directory, but their barcodes are redundant. So my first step is to rename the files by adding *_L1* for Library 1 and *_L2* for Library 2. I'll do that in python before the file extension.

# %% [markdown]
# Here's the content of the script ``add_lib_to_filename.py``:
#
# ```
# # arguments
# # [1] directory name with files to rename
# # [2] text you would like to add to the end of each filename before file extensions
#
# # assumptions
# # [1] file extention = fq.qz
# # [2] you are one directory above the directory that you want to rename the files of
# # [3] your files aren't already renamed! --- write an if else loop to make sure it hasn't been run yet when you have the time
#
# import sys
# import subprocess
#
# # make a text file that has each thing in this directory on a line; each line should be each file in the lane
#
# string1 = "" # initiate string
#
# string1 += 'ls ' + sys.argv[1] + ' > ./dircontents.txt' # add ls, wd, redirect to text file
#
# firstshell = open("getcontents_shell.txt", "w")
# firstshell.write(string1)
# firstshell.close()
#
# subprocess.call(["sh getcontents_shell.txt"], shell = True)
#
# # now that file is made for contents of directory, read that file in
# contents = open("dircontents.txt", "r")
#
#
# # second shell = renaming script
# rename_w_lib_shell = open("rename_w_lib_shell.txt", "w")
#
# string2 = ""
# string2 += "cd " + sys.argv[1] + "\n"
#
#
# # loop that will break the script if it's already run to make sure you don't rename files into something wrong!
# for line in contents:
# 	linelist = line.strip().split(".")
# 	if linelist[0][-4] == "L":
# 		print "CHECK TO SEE IF YOU HAVE ALREADY RENAMED THESE FILES. SCRIPT PAUSED AS WARNING BECAUSE FILES APPEAR RENAMED."
# 		sys.exit() # exit script
# 	else:
# 		continue
# contents.close()
#
#
#
# contents = open("dircontents.txt", "r")
# for line in contents:
# 	original = line.strip()
# 	filename_list = line.strip().split(".") # make list out of whole file name with extensions
# 	filename_wo_ext = filename_list[0]
# 	file_ext = "." + filename_list[1] + "." + filename_list[2]
# 	wordlist = filename_wo_ext.split("_") # split filename without extensions into parts by underscore
# 	newfilename = wordlist[0] + sys.argv[2] + "_" + wordlist[1]
# 	newfilename += file_ext
# 	string2 += "mv" + "\t" + original + "\t" + newfilename + "\n"
#
# rename_w_lib_shell.write(string2)
# rename_w_lib_shell.close()
# contents.close()
#
# # call renaming shell script
# subprocess.call(["sh rename_w_lib_shell.txt"], shell = True)
# ```
#
# Running the code looks like this:

# %%
# !python add_lib_to_filename.py process_radtags_out/cod_lib1 _L1

# %%
# !python add_lib_to_filename.py process_radtags_out/cod_lib2 _L2

# %% [markdown]
# Now my files are renamed with the library information after the barcode before their 1 or 2 that was used to signify forward and reverse for paired end data.
# <br><br>
# From
# <br>
# ![image](https://github.com/nclowell/FISH546/blob/master/Cod-Time-Series-Project/Notebooks/images_for_notebooks/Screen%20Shot%202016-11-16%20at%206.15.59%20PM.png?raw=true)
# <br>
# To
# ![image](https://github.com/nclowell/FISH546/blob/master/Cod-Time-Series-Project/Notebooks/images_for_notebooks/Screen%20Shot%202016-11-16%20at%206.15.48%20PM.png?raw=true)
# <br>
# <br>
# And then I can group the two directories of libraries together.
# <br>
# ![image](https://github.com/nclowell/FISH546/blob/master/Cod-Time-Series-Project/Notebooks/images_for_notebooks/Screen%20Shot%202016-11-17%20at%209.09.21%20AM.png?raw=true)
# <br>
# Now I want to run ``ustacks`` on all the files in this folder. I can use my handy dandy script I wrote a couple of weeks ago. It looks like this:
#
# ```
# ##########################################################################################
# #
# ### ``ustacks``
# #
# # PURPOSE: This step aligns identical RAD tags within an individual into stacks & provides data for calling SNPs
# # INPUT: fastq or gzfastq files
# # OUTPUT: 4 files - alleles, modules, snps, tags
# #
# #
# ### WHEN RUNNING THIS SCRIPT, YOUR INPUTS AT THE COMMAND LINE ARE:
# # python
# # {0}[pipeline filename]
# # {1}[barcodes & samples textfile]
# # {2}[start directory]
# # {3}[end directory]
# #
# ### DEPENDENCIES
# #
# # [1] You need a file where first column is barcode and second is unique sample name
# #
# ### WARNINGS
# #
# # [1] ustacks only works when your working directory is one direcotry above the folders you are
# #		calling and storing data in
# #
# ##########################################################################################
#
# # --- [A] call necessary modules
#
# import subprocess
# import sys
#
#
#
#
#
# # --- [B] Rename your files by the sample name
#
# new_file = open("new_filenames_shell.txt", "w") # new txt file
# dir = sys.argv[2] # directory files that need names changed
# firststr = "cd " + dir + "\n" + "pwd\n"
# new_file.write(firststr)
#
# myfile = open(sys.argv[1], "r")				# myfile =  tab delimited file mentioned, called after your script
#
# for line in myfile:						   # loop through each line
# 	linelist=line.strip().split()		   # splits into list by white space
# 	barcodefile1 = linelist[0] + "_1.fq.gz" # forward
# 	barcodefile2 = linelist[0] + "_2.fq.gz" # reverse
# 	samplefile1 = linelist[1] + "_1.fq.gz" # forward
# 	samplefile2 = linelist[1] + "_2.fq.gz" # reverse
# 	newstring = "mv" + "\t" + barcodefile1 + "\t" + samplefile1 + "\n" + "mv" + "\t" + barcodefile2 + "\t" + samplefile2 + "\n"
# 	# print newstring  # troubleshooting loop
# 	new_file.write(newstring)
#
# myfile.close()
# new_file.close()
#
# # run the script you just made as a shell script to rename your files
# subprocess.call(['sh new_filenames_shell.txt'], shell=True)
#
#
#
#
#
# ### --- [C] Make shell script to run all samples through command line through ``ustacks``
#
# # ``ustacks`` requires an arbitrary integer for every sample, although unclear how it gets used as it does not become the name of the file
#
#
# # name your 'from' and 'to' directories that will go in each line of your ustacks shell script
# dirfrom = sys.argv[2]
# dirto = sys.argv[3]
#
# newfile2 = open("ustacks_shell.txt", "w")	 # make ustacks shell script to run through terminal
# myfile = open("new_filenames_shell.txt", "r")	#open the file with a list of barcodes + sample IDs
#
# # dir = sys.argv[2] # directory files that need names changed
# # firststr = "cd " + dir + "\n"
# # new_file.write(firststr)
#
# dir2 = sys.argv[2] # directory with files that we want to run ustacks on
#
# ID_int = 001								# start integer counter
#
# lines = myfile.readlines()[2:] # skip first two lines because just cd and pwd
#
#
# ID_int = 001								# start integer counter
# for line in lines: 			#for each line in the barcode file
# 	linelist=line.strip().split()
# 	sampID = linelist[2] 					#save the second object as "sampID"
# 	if ID_int < 10:
# 		ustacks_code = "ustacks -t gzfastq -f " + dirfrom + "/" + sampID + " -r -d -o " + dirto + " -i 00" + str(ID_int) + " -m 5 -M 3 -p 10" + "\n"
# 								#create a line of code for ustacks that includes the new sample ID (with 2 leading 0s)
# 	elif ID_int >= 10 & ID_int < 100:
# 		ustacks_code = "ustacks -t gzfastq -f " + dirfrom + "/" + sampID + " -r -d -o " + dirto + " -i 0" + str(ID_int) + " -m 5 -M 3 -p 10" + "\n"
# 								#create a line of code for ustacks that includes the new sample ID (with 1 leading 0)
# 	else:
# 		ustacks_code = "ustacks -t gzfastq -f " + dirfrom + "/" + sampID + " -r -d -o " + dirto + " -i " + str(ID_int) + " -m 5 -M 3 -p 10" + "\n"
# 								#create a line of code for ustacks that includes the new sample ID (with no leading 0s)
# 	newfile2.write(ustacks_code)	#append this new line of code to the output file
# 	ID_int += 1
#
# myfile.close()
# newfile2.close()
#
# # run this new script through the terminal
# subprocess.call(['sh ustacks_shell.txt'], shell=True)
#
# ##########################################################################################
#
# ```
#
# And I run it like this:

# %%
# !python pypipe_ustacks.py barcodes_samplenames.txt ./process_radtags_out ./ustacks_out
# Out:
# /Volumes/Time Machine Backups/Cod-Time-Series-Data/process_radtags_out
# mv: AAACGG_L1_1.fq.gz: No such file or directory
# mv: AAACGG_L1_2.fq.gz: No such file or directory
# mv: GCCGTA_L1_1.fq.gz: No such file or directory
# mv: GCCGTA_L1_2.fq.gz: No such file or directory
# mv: ACTCTT_L1_1.fq.gz: No such file or directory
# mv: ACTCTT_L1_2.fq.gz: No such file or directory
# mv: TTCTAG_L1_1.fq.gz: No such file or directory
# mv: TTCTAG_L1_2.fq.gz: No such file or directory
# mv: ATTCCG_L1_1.fq.gz: No such file or directory
# mv: ATTCCG_L1_2.fq.gz: No such file or directory
# mv: CCGCAT_L1_1.fq.gz: No such file or directory
# mv: CCGCAT_L1_2.fq.gz: No such file or directory
# mv: CGAGGC_L1_1.fq.gz: No such file or directory
# mv: CGAGGC_L1_2.fq.gz: No such file or directory
# mv: CGCAGA_L1_1.fq.gz: No such file or directory
# mv: CGCAGA_L1_2.fq.gz: No such file or directory
# mv: GAGAGA_L1_1.fq.gz: No such file or directory
# mv: GAGAGA_L1_2.fq.gz: No such file or directory
# mv: GGGGCG_L1_1.fq.gz: No such file or directory
# mv: GGGGCG_L1_2.fq.gz: No such file or directory
# mv: TAATTC_L1_1.fq.gz: No such file or directory
# mv: TAATTC_L1_2.fq.gz: No such file or directory
# mv: TTTAAT_L1_1.fq.gz: No such file or directory
# mv: TTTAAT_L1_2.fq.gz: No such file or directory
# mv: AGCCAT_L1_1.fq.gz: No such file or directory
# mv: AGCCAT_L1_2.fq.gz: No such file or directory
# mv: AGTAGG_L1_1.fq.gz: No such file or directory
# mv: AGTAGG_L1_2.fq.gz: No such file or directory
# mv: ATAGTA_L1_1.fq.gz: No such file or directory
# mv: ATAGTA_L1_2.fq.gz: No such file or directory
# mv: CGGTCC_L1_1.fq.gz: No such file or directory
# mv: CGGTCC_L1_2.fq.gz: No such file or directory
# mv: CCATTT_L1_1.fq.gz: No such file or directory
# mv: CCATTT_L1_2.fq.gz: No such file or directory
# mv: CAGGCA_L1_1.fq.gz: No such file or directory
# mv: CAGGCA_L1_2.fq.gz: No such file or directory
# mv: GCAGAT_L1_1.fq.gz: No such file or directory
# mv: GCAGAT_L1_2.fq.gz: No such file or directory
# mv: GTCATC_L1_1.fq.gz: No such file or directory
# mv: GTCATC_L1_2.fq.gz: No such file or directory
# mv: GACTCT_L1_1.fq.gz: No such file or directory
# mv: GACTCT_L1_2.fq.gz: No such file or directory
# mv: TATCAC_L1_1.fq.gz: No such file or directory
# mv: TATCAC_L1_2.fq.gz: No such file or directory
# mv: TGGGGA_L1_1.fq.gz: No such file or directory
# mv: TGGGGA_L1_2.fq.gz: No such file or directory
# mv: TCTCGG_L1_1.fq.gz: No such file or directory
# mv: TCTCGG_L1_2.fq.gz: No such file or directory
# mv: TGACAA_L2_1.fq.gz: No such file or directory
# mv: TGACAA_L2_2.fq.gz: No such file or directory
# mv: AATATC_L2_1.fq.gz: No such file or directory
# mv: AATATC_L2_2.fq.gz: No such file or directory
# mv: ACAGCG_L2_1.fq.gz: No such file or directory
# mv: ACAGCG_L2_2.fq.gz: No such file or directory
# mv: GATCGT_L2_1.fq.gz: No such file or directory
# mv: GATCGT_L2_2.fq.gz: No such file or directory
# mv: GGTTTG_L2_1.fq.gz: No such file or directory
# mv: GGTTTG_L2_2.fq.gz: No such file or directory
# mv: CTCGCC_L2_1.fq.gz: No such file or directory
# mv: CTCGCC_L2_2.fq.gz: No such file or directory
# mv: GTGCCT_L2_1.fq.gz: No such file or directory
# mv: GTGCCT_L2_2.fq.gz: No such file or directory
# mv: TAGTAT_L2_1.fq.gz: No such file or directory
# mv: TAGTAT_L2_2.fq.gz: No such file or directory
# mv: ACAAGA_L2_1.fq.gz: No such file or directory
# mv: ACAAGA_L2_2.fq.gz: No such file or directory
# mv: TTCCGT_L2_1.fq.gz: No such file or directory
# mv: TTCCGT_L2_2.fq.gz: No such file or directory
# mv: CCCTAA_L2_1.fq.gz: No such file or directory
# mv: CCCTAA_L2_2.fq.gz: No such file or directory
# mv: AGGGTC_L2_1.fq.gz: No such file or directory
# mv: AGGGTC_L2_2.fq.gz: No such file or directory
# mv: CAATCG_L2_1.fq.gz: No such file or directory
# mv: CAATCG_L2_2.fq.gz: No such file or directory
# mv: GAACCA_L2_1.fq.gz: No such file or directory
# mv: GAACCA_L2_2.fq.gz: No such file or directory
# mv: TCGGAC_L2_1.fq.gz: No such file or directory
# mv: TCGGAC_L2_2.fq.gz: No such file or directory
# mv: ATGTTG_L2_1.fq.gz: No such file or directory
# mv: ATGTTG_L2_2.fq.gz: No such file or directory
# mv: AACTGA_L2_1.fq.gz: No such file or directory
# mv: AACTGA_L2_2.fq.gz: No such file or directory
# mv: TCTTCT_L2_1.fq.gz: No such file or directory
# mv: TCTTCT_L2_2.fq.gz: No such file or directory
# mv: GGACTT_L2_1.fq.gz: No such file or directory
# mv: GGACTT_L2_2.fq.gz: No such file or directory
# mv: GGGCGC_L2_1.fq.gz: No such file or directory
# mv: GGGCGC_L2_2.fq.gz: No such file or directory
# mv: ATCAAA_L2_1.fq.gz: No such file or directory
# mv: ATCAAA_L2_2.fq.gz: No such file or directory
# mv: GGCAAG_L2_1.fq.gz: No such file or directory
# mv: GGCAAG_L2_2.fq.gz: No such file or directory
# mv: CATACT_L2_1.fq.gz: No such file or directory
# mv: CATACT_L2_2.fq.gz: No such file or directory
# mv: CGCGTG_L2_1.fq.gz: No such file or directory
# mv: CGCGTG_L2_2.fq.gz: No such file or directory
# mv: AACGTT_L2_1.fq.gz: No such file or directory
# mv: AACGTT_L2_2.fq.gz: No such file or directory
# mv: AAGACG_L2_1.fq.gz: No such file or directory
# mv: AAGACG_L2_2.fq.gz: No such file or directory
# mv: AAGCTA_L2_1.fq.gz: No such file or directory
# mv: AAGCTA_L2_2.fq.gz: No such file or directory
# mv: AATGAG_L2_1.fq.gz: No such file or directory
# mv: AATGAG_L2_2.fq.gz: No such file or directory
# mv: ACATAC_L2_1.fq.gz: No such file or directory
# mv: ACATAC_L2_2.fq.gz: No such file or directory
# mv: ACCATG_L2_1.fq.gz: No such file or directory
# mv: ACCATG_L2_2.fq.gz: No such file or directory
# mv: ACCCCC_L2_1.fq.gz: No such file or directory
# mv: ACCCCC_L2_2.fq.gz: No such file or directory
# mv: ACTGGC_L2_1.fq.gz: No such file or directory
# mv: ACTGGC_L2_2.fq.gz: No such file or directory
# mv: AGCGCA_L2_1.fq.gz: No such file or directory
# mv: AGCGCA_L2_2.fq.gz: No such file or directory
# mv: AGGTGT_L2_1.fq.gz: No such file or directory
# mv: AGGTGT_L2_2.fq.gz: No such file or directory
# mv: AGTTAA_L2_1.fq.gz: No such file or directory
# mv: AGTTAA_L2_2.fq.gz: No such file or directory
# mv: ATGCAC_L2_1.fq.gz: No such file or directory
# mv: ATGCAC_L2_2.fq.gz: No such file or directory
# mv: GAAATG_L1_1.fq.gz: No such file or directory
# mv: GAAATG_L1_2.fq.gz: No such file or directory
# mv: GACGAC_L1_1.fq.gz: No such file or directory
# mv: GACGAC_L1_2.fq.gz: No such file or directory
# mv: GCATGG_L1_1.fq.gz: No such file or directory
# mv: GCATGG_L1_2.fq.gz: No such file or directory
# mv: GCGACC_L1_1.fq.gz: No such file or directory
# mv: GCGACC_L1_2.fq.gz: No such file or directory
# mv: GCGCTG_L1_1.fq.gz: No such file or directory
# mv: GCGCTG_L1_2.fq.gz: No such file or directory
# mv: GCTCAA_L1_1.fq.gz: No such file or directory
# mv: GCTCAA_L1_2.fq.gz: No such file or directory
# mv: GGTACA_L1_1.fq.gz: No such file or directory
# mv: GGTACA_L1_2.fq.gz: No such file or directory
# mv: GTAAGT_L1_1.fq.gz: No such file or directory
# mv: GTAAGT_L1_2.fq.gz: No such file or directory
# mv: GTATCC_L1_1.fq.gz: No such file or directory
# mv: GTATCC_L1_2.fq.gz: No such file or directory
# mv: GTGTAA_L1_1.fq.gz: No such file or directory
# mv: GTGTAA_L1_2.fq.gz: No such file or directory
# mv: GTTGGA_L1_1.fq.gz: No such file or directory
# mv: GTTGGA_L1_2.fq.gz: No such file or directory
# mv: TTTGTC_L1_1.fq.gz: No such file or directory
# mv: TTTGTC_L1_2.fq.gz: No such file or directory
# mv: TAAGCT_L2_1.fq.gz: No such file or directory
# mv: TAAGCT_L2_2.fq.gz: No such file or directory
# mv: TACACA_L2_1.fq.gz: No such file or directory
# mv: TACACA_L2_2.fq.gz: No such file or directory
# mv: TACGGG_L2_1.fq.gz: No such file or directory
# mv: TACGGG_L2_2.fq.gz: No such file or directory
# mv: TCAAAG_L2_1.fq.gz: No such file or directory
# mv: TCAAAG_L2_2.fq.gz: No such file or directory
# mv: TCCTGC_L2_1.fq.gz: No such file or directory
# mv: TCCTGC_L2_2.fq.gz: No such file or directory
# mv: TCGCCA_L2_1.fq.gz: No such file or directory
# mv: TCGCCA_L2_2.fq.gz: No such file or directory
# mv: TGAACC_L2_1.fq.gz: No such file or directory
# mv: TGAACC_L2_2.fq.gz: No such file or directory
# mv: TGCCCG_L2_1.fq.gz: No such file or directory
# mv: TGCCCG_L2_2.fq.gz: No such file or directory
# mv: TGCTTA_L2_1.fq.gz: No such file or directory
# mv: TGCTTA_L2_2.fq.gz: No such file or directory
# mv: TTATGA_L2_1.fq.gz: No such file or directory
# mv: TTATGA_L2_2.fq.gz: No such file or directory
# mv: TTGAGC_L2_1.fq.gz: No such file or directory
# mv: TTGAGC_L2_2.fq.gz: No such file or directory
# mv: GAAATG_L2_1.fq.gz: No such file or directory
# mv: GAAATG_L2_2.fq.gz: No such file or directory
# mv: GACGAC_L2_1.fq.gz: No such file or directory
# mv: GACGAC_L2_2.fq.gz: No such file or directory
# mv: GCATGG_L2_1.fq.gz: No such file or directory
# mv: GCATGG_L2_2.fq.gz: No such file or directory
# mv: GCGACC_L2_1.fq.gz: No such file or directory
# mv: GCGACC_L2_2.fq.gz: No such file or directory
# mv: GCGCTG_L2_1.fq.gz: No such file or directory
# mv: GCGCTG_L2_2.fq.gz: No such file or directory
# mv: GCTCAA_L2_1.fq.gz: No such file or directory
# mv: GCTCAA_L2_2.fq.gz: No such file or directory
# mv: GGTACA_L2_1.fq.gz: No such file or directory
# mv: GGTACA_L2_2.fq.gz: No such file or directory
# mv: GTAAGT_L2_1.fq.gz: No such file or directory
# mv: GTAAGT_L2_2.fq.gz: No such file or directory
# mv: GTATCC_L2_1.fq.gz: No such file or directory
# mv: GTATCC_L2_2.fq.gz: No such file or directory
# mv: GTGTAA_L2_1.fq.gz: No such file or directory
# mv: GTGTAA_L2_2.fq.gz: No such file or directory
# mv: GTTGGA_L2_1.fq.gz: No such file or directory
# mv: GTTGGA_L2_2.fq.gz: No such file or directory
# mv: TTTGTC_L2_1.fq.gz: No such file or directory
# mv: TTTGTC_L2_2.fq.gz: No such file or directory
# mv: TAAGCT_L1_1.fq.gz: No such file or directory
# mv: TAAGCT_L1_2.fq.gz: No such file or directory
# mv: TACACA_L1_1.fq.gz: No such file or directory
# mv: TACACA_L1_2.fq.gz: No such file or directory
# mv: TACGGG_L1_1.fq.gz: No such file or directory
# mv: TACGGG_L1_2.fq.gz: No such file or directory
# mv: TCAAAG_L1_1.fq.gz: No such file or directory
# mv: TCAAAG_L1_2.fq.gz: No such file or directory
# mv: TCCTGC_L1_1.fq.gz: No such file or directory
# mv: TCCTGC_L1_2.fq.gz: No such file or directory
# mv: TCGCCA_L1_1.fq.gz: No such file or directory
# mv: TCGCCA_L1_2.fq.gz: No such file or directory
# mv: TGAACC_L1_1.fq.gz: No such file or directory
# mv: TGAACC_L1_2.fq.gz: No such file or directory
# mv: TGCCCG_L1_1.fq.gz: No such file or directory
# mv: TGCCCG_L1_2.fq.gz: No such file or directory
# mv: TGCTTA_L1_1.fq.gz: No such file or directory
# mv: TGCTTA_L1_2.fq.gz: No such file or directory
# mv: TTATGA_L1_1.fq.gz: No such file or directory
# mv: TTATGA_L1_2.fq.gz: No such file or directory
# mv: TTGAGC_L1_1.fq.gz: No such file or directory
# mv: TTGAGC_L1_2.fq.gz: No such file or directory
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2005_387_1.fq.gz
# Loading RAD-Tags...done
# Loaded 337044 RAD-Tags.
#   Inserted 107931 elements into the RAD-Tags hash map.
#   196 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 9.87009; Std Dev: 16.9809; Max: 1341
# Deleveraging trigger: 27; Removal trigger: 44
# 21754 initial stacks were populated; 86177 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 457 stacks.
#   21390 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 9.13598; Std Dev: 33.5736; Max: 44
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   21390 stacks merged into 20263 stacks; deleveraged 123 stacks; removed 47 stacks.
# After merging, coverage depth Mean: 9.5447; Std Dev: 34.6834; Max: 86
# Merging remainder radtags
#   122330 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 41293 remainder reads; unable to match 81037 remainder reads.
# After remainders merged, coverage depth Mean: 11.5967; Std Dev: 34.9479; Max: 252
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 256007
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2005_387_1.fq.gz... read 337044 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2005_387_2.fq.gz
# Loading RAD-Tags...done
# Loaded 337044 RAD-Tags.
#   Inserted 217488 elements into the RAD-Tags hash map.
#   3228 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 5.88971; Std Dev: 2.26641; Max: 65
# Deleveraging trigger: 8; Removal trigger: 10
# 5567 initial stacks were populated; 211921 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 164 stacks.
#   5530 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 5.64131; Std Dev: 3.53766; Max: 10
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   5530 stacks merged into 5458 stacks; deleveraged 8 stacks; removed 0 stacks.
# After merging, coverage depth Mean: 5.7175; Std Dev: 3.66137; Max: 21
# Merging remainder radtags
#   304256 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 4983 remainder reads; unable to match 299273 remainder reads.
# After remainders merged, coverage depth Mean: 6.65222; Std Dev: 4.94798; Max: 78
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 37771
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2005_387_2.fq.gz... read 337044 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2005_388_1.fq.gz
# Loading RAD-Tags...done
# Loaded 102934 RAD-Tags.
#   Inserted 47899 elements into the RAD-Tags hash map.
#   39 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 7.47604; Std Dev: 9.10383; Max: 308
# Deleveraging trigger: 17; Removal trigger: 26
# 4758 initial stacks were populated; 43141 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 140 stacks.
#   4652 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 6.82265; Std Dev: 16.715; Max: 26
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   4652 stacks merged into 4494 stacks; deleveraged 28 stacks; removed 8 stacks.
# After merging, coverage depth Mean: 6.99483; Std Dev: 17.1908; Max: 40
# Merging remainder radtags
#   67363 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 6914 remainder reads; unable to match 60449 remainder reads.
# After remainders merged, coverage depth Mean: 8.54784; Std Dev: 17.7987; Max: 106
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 42485
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2005_388_1.fq.gz... read 102934 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2005_388_2.fq.gz
# Loading RAD-Tags...done
# Loaded 102934 RAD-Tags.
#   Inserted 68647 elements into the RAD-Tags hash map.
#   989 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 5.63989; Std Dev: 1.29719; Max: 28
# Deleveraging trigger: 7; Removal trigger: 8
# 1494 initial stacks were populated; 67153 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 39 stacks.
#   1491 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 5.50378; Std Dev: 2.72755; Max: 8
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   1491 stacks merged into 1486 stacks; deleveraged 0 stacks; removed 0 stacks.
# After merging, coverage depth Mean: 5.52276; Std Dev: 2.75485; Max: 13
# Merging remainder radtags
#   94508 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 884 remainder reads; unable to match 93624 remainder reads.
# After remainders merged, coverage depth Mean: 6.13241; Std Dev: 3.36175; Max: 33
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 9310
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2005_388_2.fq.gz... read 102934 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2005_389_1.fq.gz
# Loading RAD-Tags...done
# Loaded 383344 RAD-Tags.
#   Inserted 121511 elements into the RAD-Tags hash map.
#   186 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 10.3051; Std Dev: 18.8839; Max: 1699
# Deleveraging trigger: 29; Removal trigger: 48
# 24055 initial stacks were populated; 97456 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 558 stacks.
#   23600 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 9.51347; Std Dev: 37.3479; Max: 48
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   23600 stacks merged into 22247 stacks; deleveraged 135 stacks; removed 45 stacks.
# After merging, coverage depth Mean: 9.9828; Std Dev: 38.6664; Max: 86
# Merging remainder radtags
#   135455 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 50659 remainder reads; unable to match 84796 remainder reads.
# After remainders merged, coverage depth Mean: 12.2752; Std Dev: 38.896; Max: 164
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 298548
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2005_389_1.fq.gz... read 383344 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2005_389_2.fq.gz
# Loading RAD-Tags...done
# Loaded 383344 RAD-Tags.
#   Inserted 246397 elements into the RAD-Tags hash map.
#   3653 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 5.95825; Std Dev: 2.46478; Max: 73
# Deleveraging trigger: 8; Removal trigger: 11
# 6659 initial stacks were populated; 239738 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 208 stacks.
#   6588 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 5.67958; Std Dev: 3.93443; Max: 11
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   6588 stacks merged into 6483 stacks; deleveraged 11 stacks; removed 0 stacks.
# After merging, coverage depth Mean: 5.77356; Std Dev: 4.09073; Max: 27
# Merging remainder radtags
#   343668 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 6053 remainder reads; unable to match 337615 remainder reads.
# After remainders merged, coverage depth Mean: 6.72739; Std Dev: 5.26791; Max: 55
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 45729
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2005_389_2.fq.gz... read 383344 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2005_457_1.fq.gz
# Loading RAD-Tags...1M...2M...done
# Loaded 2908839 RAD-Tags.
#   Inserted 512509 elements into the RAD-Tags hash map.
#   1310 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 50.5151; Std Dev: 109.249; Max: 15090
# Deleveraging trigger: 160; Removal trigger: 269
# 47258 initial stacks were populated; 465251 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1433 stacks.
#   45990 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 47.1101; Std Dev: 218.955; Max: 269
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   45990 stacks merged into 39554 stacks; deleveraged 313 stacks; removed 120 stacks.
# After merging, coverage depth Mean: 54.0858; Std Dev: 236.829; Max: 467
# Merging remainder radtags
#   521596 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 377873 remainder reads; unable to match 143723 remainder reads.
# After remainders merged, coverage depth Mean: 63.7085; Std Dev: 237.286; Max: 1034
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 2765116
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2005_457_1.fq.gz... read 2908839 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2005_457_2.fq.gz
# Loading RAD-Tags...1M...2M...done
# Loaded 2908839 RAD-Tags.
#   Inserted 1846417 elements into the RAD-Tags hash map.
#   26708 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 6.5805; Std Dev: 6.03966; Max: 279
# Deleveraging trigger: 13; Removal trigger: 19
# 57738 initial stacks were populated; 1788679 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1756 stacks.
#   56605 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 6.04875; Std Dev: 9.35332; Max: 19
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   56605 stacks merged into 55173 stacks; deleveraged 212 stacks; removed 36 stacks.
# After merging, coverage depth Mean: 6.18707; Std Dev: 9.62445; Max: 46
# Merging remainder radtags
#   2528894 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 77675 remainder reads; unable to match 2451219 remainder reads.
# After remainders merged, coverage depth Mean: 7.61193; Std Dev: 10.9441; Max: 221
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 457620
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2005_457_2.fq.gz... read 2908839 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2009_172_1.fq.gz
# Loading RAD-Tags...done
# Loaded 37751 RAD-Tags.
#   Inserted 20915 elements into the RAD-Tags hash map.
#   15 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 6.83012; Std Dev: 5.30218; Max: 102
# Deleveraging trigger: 12; Removal trigger: 17
# 1142 initial stacks were populated; 19773 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 50 stacks.
#   1112 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 6.1511; Std Dev: 10.4541; Max: 16
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   1112 stacks merged into 1084 stacks; deleveraged 2 stacks; removed 0 stacks.
# After merging, coverage depth Mean: 6.31297; Std Dev: 10.6624; Max: 25
# Merging remainder radtags
#   29951 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 1587 remainder reads; unable to match 28364 remainder reads.
# After remainders merged, coverage depth Mean: 7.80451; Std Dev: 11.6801; Max: 68
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 9387
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2009_172_1.fq.gz... read 37751 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2009_172_2.fq.gz
# Loading RAD-Tags...done
# Loaded 37751 RAD-Tags.
#   Inserted 25843 elements into the RAD-Tags hash map.
#   349 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 5.45666; Std Dev: 0.814802; Max: 10
# Deleveraging trigger: 6; Removal trigger: 7
# 473 initial stacks were populated; 25370 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 14 stacks.
#   473 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 5.37037; Std Dev: 2.46454; Max: 7
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   473 stacks merged into 473 stacks; deleveraged 0 stacks; removed 0 stacks.
# After merging, coverage depth Mean: 5.37037; Std Dev: 2.46454; Max: 7
# Merging remainder radtags
#   35170 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 179 remainder reads; unable to match 34991 remainder reads.
# After remainders merged, coverage depth Mean: 5.76035; Std Dev: 2.93145; Max: 26
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 2760
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2009_172_2.fq.gz... read 37751 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_114_1.fq.gz
# Loading RAD-Tags...1M...2M...3M...4M...done
# Loaded 4427652 RAD-Tags.
#   Inserted 723567 elements into the RAD-Tags hash map.
#   2040 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 75.6356; Std Dev: 181.781; Max: 25990
# Deleveraging trigger: 257; Removal trigger: 439
# 48752 initial stacks were populated; 674815 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1748 stacks.
#   47157 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 70.6055; Std Dev: 382.219; Max: 437
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   47157 stacks merged into 40480 stacks; deleveraged 349 stacks; removed 157 stacks.
# After merging, coverage depth Mean: 81.1733; Std Dev: 413.959; Max: 807
# Merging remainder radtags
#   740264 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 529863 remainder reads; unable to match 210401 remainder reads.
# After remainders merged, coverage depth Mean: 94.3638; Std Dev: 414.474; Max: 1473
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 4217251
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_114_1.fq.gz... read 4427652 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_114_2.fq.gz
# Loading RAD-Tags...1M...2M...3M...4M...done
# Loaded 4427652 RAD-Tags.
#   Inserted 2788850 elements into the RAD-Tags hash map.
#   41247 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 6.89688; Std Dev: 8.195; Max: 523
# Deleveraging trigger: 15; Removal trigger: 23
# 95561 initial stacks were populated; 2693289 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 3076 stacks.
#   93448 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 6.21576; Std Dev: 12.8153; Max: 23
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   93448 stacks merged into 90643 stacks; deleveraged 450 stacks; removed 99 stacks.
# After merging, coverage depth Mean: 6.37406; Std Dev: 13.1731; Max: 48
# Merging remainder radtags
#   3768579 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 143237 remainder reads; unable to match 3625342 remainder reads.
# After remainders merged, coverage depth Mean: 7.97303; Std Dev: 14.5501; Max: 371
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 802310
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_114_2.fq.gz... read 4427652 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_115_1.fq.gz
# Loading RAD-Tags...1M...2M...3M...done
# Loaded 3143244 RAD-Tags.
#   Inserted 519706 elements into the RAD-Tags hash map.
#   1414 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 56.1717; Std Dev: 118.954; Max: 13584
# Deleveraging trigger: 175; Removal trigger: 294
# 46678 initial stacks were populated; 473028 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1387 stacks.
#   45461 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 52.0076; Std Dev: 252.903; Max: 294
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   45461 stacks merged into 39684 stacks; deleveraged 304 stacks; removed 113 stacks.
# After merging, coverage depth Mean: 58.8407; Std Dev: 271.558; Max: 482
# Merging remainder radtags
#   521261 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 366671 remainder reads; unable to match 154590 remainder reads.
# After remainders merged, coverage depth Mean: 68.1469; Std Dev: 272.165; Max: 2225
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 2988654
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_115_1.fq.gz... read 3143244 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_115_2.fq.gz
# Loading RAD-Tags...1M...2M...3M...done
# Loaded 3143244 RAD-Tags.
#   Inserted 2040198 elements into the RAD-Tags hash map.
#   28805 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 6.70175; Std Dev: 6.87525; Max: 321
# Deleveraging trigger: 14; Removal trigger: 20
# 57831 initial stacks were populated; 1982367 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1953 stacks.
#   56555 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 6.07221; Std Dev: 10.5137; Max: 20
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   56555 stacks merged into 54958 stacks; deleveraged 255 stacks; removed 54 stacks.
# After merging, coverage depth Mean: 6.21912; Std Dev: 10.8281; Max: 41
# Merging remainder radtags
#   2755675 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 87172 remainder reads; unable to match 2668503 remainder reads.
# After remainders merged, coverage depth Mean: 7.82665; Std Dev: 12.2677; Max: 259
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 474741
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_115_2.fq.gz... read 3143244 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_116_1.fq.gz
# Loading RAD-Tags...1M...2M...done
# Loaded 2778596 RAD-Tags.
#   Inserted 477610 elements into the RAD-Tags hash map.
#   1321 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 50.0551; Std Dev: 133.027; Max: 17419
# Deleveraging trigger: 183; Removal trigger: 316
# 46043 initial stacks were populated; 431567 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1367 stacks.
#   44799 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 46.4636; Std Dev: 273.869; Max: 312
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   44799 stacks merged into 39063 stacks; deleveraged 301 stacks; removed 130 stacks.
# After merging, coverage depth Mean: 52.3894; Std Dev: 294.352; Max: 513
# Merging remainder radtags
#   473911 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 333431 remainder reads; unable to match 140480 remainder reads.
# After remainders merged, coverage depth Mean: 60.9808; Std Dev: 294.644; Max: 583
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 2638116
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_116_1.fq.gz... read 2778596 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_116_2.fq.gz
# Loading RAD-Tags...1M...2M...done
# Loaded 2778596 RAD-Tags.
#   Inserted 1801256 elements into the RAD-Tags hash map.
#   25736 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 6.88259; Std Dev: 8.3336; Max: 356
# Deleveraging trigger: 15; Removal trigger: 24
# 49929 initial stacks were populated; 1751327 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1858 stacks.
#   48620 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 6.09473; Std Dev: 12.8187; Max: 24
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   48620 stacks merged into 47147 stacks; deleveraged 220 stacks; removed 56 stacks.
# After merging, coverage depth Mean: 6.24432; Std Dev: 13.1908; Max: 54
# Merging remainder radtags
#   2434955 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 77066 remainder reads; unable to match 2357889 remainder reads.
# After remainders merged, coverage depth Mean: 7.90015; Std Dev: 14.673; Max: 249
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 420707
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_116_2.fq.gz... read 2778596 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_117_1.fq.gz
# Loading RAD-Tags...1M...2M...3M...4M...done
# Loaded 4052820 RAD-Tags.
#   Inserted 662406 elements into the RAD-Tags hash map.
#   1808 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 68.5725; Std Dev: 164.084; Max: 22108
# Deleveraging trigger: 233; Removal trigger: 397
# 49207 initial stacks were populated; 613199 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1802 stacks.
#   47560 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 64.0854; Std Dev: 333.468; Max: 396
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   47560 stacks merged into 40584 stacks; deleveraged 373 stacks; removed 144 stacks.
# After merging, coverage depth Mean: 74.0004; Std Dev: 362.204; Max: 628
# Merging remainder radtags
#   678572 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 478542 remainder reads; unable to match 200030 remainder reads.
# After remainders merged, coverage depth Mean: 85.8793; Std Dev: 362.628; Max: 817
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 3852790
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_117_1.fq.gz... read 4052820 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_117_2.fq.gz
# Loading RAD-Tags...1M...2M...3M...4M...done
# Loaded 4052820 RAD-Tags.
#   Inserted 2540585 elements into the RAD-Tags hash map.
#   37645 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 6.80969; Std Dev: 7.54951; Max: 492
# Deleveraging trigger: 14; Removal trigger: 22
# 87804 initial stacks were populated; 2452781 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 2752 stacks.
#   85945 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 6.18089; Std Dev: 11.5834; Max: 22
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   85945 stacks merged into 83481 stacks; deleveraged 391 stacks; removed 83 stacks.
# After merging, coverage depth Mean: 6.33396; Std Dev: 11.9129; Max: 46
# Merging remainder radtags
#   3454902 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 125862 remainder reads; unable to match 3329040 remainder reads.
# After remainders merged, coverage depth Mean: 7.85946; Std Dev: 13.2188; Max: 254
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 723780
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_117_2.fq.gz... read 4052820 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_118_1.fq.gz
# Loading RAD-Tags...1M...2M...3M...4M...done
# Loaded 4671321 RAD-Tags.
#   Inserted 750432 elements into the RAD-Tags hash map.
#   2150 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 78.3372; Std Dev: 172.151; Max: 26924
# Deleveraging trigger: 250; Removal trigger: 423
# 49714 initial stacks were populated; 700718 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1871 stacks.
#   48003 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 73.4917; Std Dev: 374.846; Max: 422
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   48003 stacks merged into 40908 stacks; deleveraged 381 stacks; removed 165 stacks.
# After merging, coverage depth Mean: 85.1; Std Dev: 407.442; Max: 776
# Merging remainder radtags
#   776865 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 565892 remainder reads; unable to match 210973 remainder reads.
# After remainders merged, coverage depth Mean: 99.044; Std Dev: 408.065; Max: 2409
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 4460348
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_118_1.fq.gz... read 4671321 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_118_2.fq.gz
# Loading RAD-Tags...1M...2M...3M...4M...done
# Loaded 4671321 RAD-Tags.
#   Inserted 2917632 elements into the RAD-Tags hash map.
#   42637 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 6.80444; Std Dev: 7.58676; Max: 546
# Deleveraging trigger: 14; Removal trigger: 22
# 100899 initial stacks were populated; 2816733 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 75 (76 k-mers per read); 1 k-mer hits required.
# Removing repetitive stacks.
#   Removed 3071 stacks.
#   98799 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 6.19977; Std Dev: 11.9405; Max: 22
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 37 (114 k-mers per read); 3 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   98799 stacks merged into 95720 stacks; deleveraged 489 stacks; removed 106 stacks.
# After merging, coverage depth Mean: 6.36344; Std Dev: 12.311; Max: 51
# Merging remainder radtags
#   3984760 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 25 (126 k-mers per read); 1 k-mer hits required.
#   Matched 146611 remainder reads; unable to match 3838149 remainder reads.
# After remainders merged, coverage depth Mean: 7.91253; Std Dev: 13.6328; Max: 424
# Calling final consensus sequences, invoking SNP-calling model...
# Number of utilized reads: 833172
# Writing loci, SNPs, and alleles to './ustacks_out/'...
#   Refetching sequencing IDs from ./process_radtags_out/2010_118_2.fq.gz... read 4671321 sequence IDs.
# done.
# ustacks paramters selected:
#   Min depth of coverage to create a stack: 5
#   Max distance allowed between stacks: 3
#   Max distance allowed to align secondary reads: 5
#   Max number of stacks allowed per de novo locus: 3
#   Deleveraging algorithm: enabled
#   Removal algorithm: enabled
#   Model type: SNP
#   Alpha significance level for model: 0.05
#   Gapped alignments: disabled
# Parsing ./process_radtags_out/2010_119_1.fq.gz
# Loading RAD-Tags...1M...2M...3M...done
# Loaded 3669174 RAD-Tags.
#   Inserted 614790 elements into the RAD-Tags hash map.
#   1720 reads contained uncalled nucleotides that were modified.
# Initial coverage mean: 62.6005; Std Dev: 136.23; Max: 16601
# Deleveraging trigger: 199; Removal trigger: 335
# 48554 initial stacks were populated; 566236 stacks were set aside as secondary reads.
# Calculating distance for removing repetitive stacks.
#   Distance allowed between stacks: 1; searching with a k-mer length of 71 (74 k-mers per read); 3 k-mer hits required.
# Removing repetitive stacks.
#   Removed 1623 stacks.
#   47108 stacks remain for merging.
# Post-Repeat Removal, coverage depth Mean: 58.4327; Std Dev: 274.496; Max: 327
# Calculating distance between stacks...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
# Merging stacks, maximum allowed distance: 3 nucleotide(s)
#   47108 stacks merged into 40388 stacks; deleveraged 328 stacks; removed 132 stacks.
# After merging, coverage depth Mean: 67.3503; Std Dev: 297.349; Max: 571
# Merging remainder radtags
#   629670 remainder sequences left to merge.
#   Distance allowed between stacks: 5; searching with a k-mer length of 23 (122 k-mers per read); 7 k-mer hits required.
#   Matched 448394 remainder reads; unable to match 181276 remainder reads.
# After remainders merged, coverage depth Mean: 78.5381; Std Dev: 297.788; Max: 788
# Calling final consensus sequences, invoking SNP-calling model...
# ^CTraceback (most recent call last):
#   File "pypipe_ustacks.py", line 109, in <module>

# %% [markdown]
# The kernel crashed some point in the middle of the night so I don't have all my data :( going to try to rerun some of it now.
#
# I'm only going to use the forward reads for this class project, so I manually removed the reverse read files that ustacks made and put them in a different folder.
#
# ## ``cstacks``
#
# Then, I run cstacks on 10 samples that represent the samples with the most reads.
#
# <br>
# My ``cstacks`` script looks like this:
#
# ```
# ##########################################################################################
# #
# ###--- ``cstacks`` script
# #
# # PURPOSE: ustacks creates a catalog from a subset of individuals to call SNPs
# # INPUT: ustacks out put files for specified number of individuals with most sequence reads
# # OUTPUT: catalog file + associated files
# #
# #### WHEN RUNNING THIS SCRIPT, INPUTS AT THE COMMAND LINE ARE:
# # python
# # {0}[pypipe_cstacks.py]
# # {1}[shell script with changed file names]
# # {2}[directory of input files]
# # {3}[# individuals for cstacks]
# # {4}[batch number]
# # {5}[output directory]
# # {6}[num mismatches allowed]
# # {7}[num threads]
# #
# ### DEPENDENCIES:
# # [1] Your file names coming out of ustacks cannot have a period other than before file extension (not sure if true! check?)
# #
# ### WARNINGS:
# # [1] If you have to rerun this script, it will append onto it! make sure no file w name or else won't even run!
# #
# ##########################################################################################
#
# ### --- [A] Call necessary modules
#
# import sys
# import subprocess
#
#
#
#
#
# ### --- [B] Count lines in each sequence file
#
# myfile = open(sys.argv[1], "r")	#open the file with your list of barcodes and sample IDs
# lines = myfile.readlines()[2:]
#
#
# dirfrom = sys.argv[2] # get directory for input files
# firststr = "cd " + sys.argv[2] + "\n" # write first line of shell to cd to this directory
#
# filestring = ""
# filestring += firststr
#
# samplename_list = [] # to be used in loop later in this script
#
# for line in lines: 					#for each line in the barcode file
# 	linelist = line.strip().split()		#make a list of character strings broken by tabs
# 	sampID = linelist[2]				#pick out file name
# 	samplename_list.append(sampID)
# 	newstring = "gunzip -c " + sampID + " | wc -l >> ../cstacks_linecount.txt\n" # make line of code to run at command line
# 	filestring += newstring # add to a list of strings we'll write to a file
# myfile.close()
#
#
# #create a new file where the ustacks code will go, write string to file, close
# newfile = open("cstacks_linecount_shell.txt", "w")
# newfile.write(filestring)
# newfile.close()
#
# # run shell script that will calculate line counts
# # subprocess.call(['sh cstacks_linecount_shell.txt'], shell=True)
# #
#
# #
# #
# #
# # ### --- [C] Get sample names for specified # of samples with most sequence reads
# #
# linecounts = open("cstacks_linecount.txt", "r") # read in line counts file
# linecounts_list = [] # initiate a list for the line counts so I can get.item later
#
# for line in linecounts:
# 	count = line.strip().split() # get line count
# 	linecounts_list.append(line)
#
# list_samp_ct = [] # initiate empty list
# i = 0 # start counter
#
# # --- CHECK^ if lists look normal
# # print "sample name list "
# # print samplename_list
# # print "line counts list "
# # print linecounts_list
#
# for item in linecounts_list:
# 	new_item = [samplename_list[i], linecounts_list[i]]
# 	list_samp_ct.append(new_item)
# 	i += 1
#
# def getKey(item): # so that sorted will sort by second item in list
# 	return item[1]
# sortedlist = sorted(list_samp_ct, key = getKey, reverse = True)
# # print sortedlist # CHECK^
#
# with open('all_sorted_name_counts.txt', 'w') as file:
#     file.writelines('\t'.join(i) + '\n' for i in sortedlist) # makes file
#
#
#
#
#
# ### --- [D] Write and run shell script for ``cstacks``
#
#
# # ---------
# # I had an automated way to pick the ten samples with most reads, but my ustacks run on 20161108 failed halfway throgh
# # and so I have less samples. So I manually picked ten with the most reads of the files that went through ustacks
#
# # so hash comment this out in the future!
#
#
# samples_for_use = []
# foruse = open("files_for_cstacks.txt", "r")
# for line in foruse:
# 	linelist = line.strip().split()
# 	samples_for_use.append(linelist[0])
# foruse.close()
#
#
#
# #----------
#
#
#
# cstacks_shell = ""
# dirstr = "cd " + sys.argv[2] + "\n"
# firststr = "cstacks -b " + sys.argv[4] + " "
# cstacks_shell += firststr
#
# endrange = int(sys.argv[3]) # set end of range for loop
# for i in range(0, endrange):
# 	filename = samples_for_use[i]
# 	trmd_filename = filename.rsplit(".",2)[0]
# 	# print trmd_filename # CHECK^
# 	string = "-s " + trmd_filename + " "
# 	cstacks_shell += string
# laststr = "-o " + sys.argv[5] + " -n " + sys.argv[6] + " -p " + sys.argv[7]
# cstacks_shell += laststr
# # print cstacks_shell # CHECK^
#
# cstacks_shell_txt = open("cstacks_shell.txt", "w")
# cstacks_shell_txt.write(cstacks_shell)
# cstacks_shell_txt.close()
#
# # run shell script
# subprocess.call(["sh cstacks_shell.txt"], shell = True)
#
# ##########################################################################################
#
#
# ##########################################################################################
#
#
# ### --- DOCUMENTATION FOR CSTACKS
#
# # cstacks -b batch_id -s sample_file [-s sample_file_2 ...] [-o path] [-n num] [-g] [-p num_threads] [--catalog path] [-h]
# # p — enable parallel execution with num_threads threads.
# # b — MySQL ID of this batch.
# # s — TSV file from which to load radtags.
# # o — output path to write results.
# # m — include tags in the catalog that match to more than one entry.
# # n — number of mismatches allowed between sample tags when generating the catalog.
# # g — base catalog matching on genomic location, not sequence identity.
# # h — display this help messsage.
# # Catalog editing:
# #
# # --catalog [path] — provide the path to an existing catalog. cstacks will add data to this existing catalog.
# # Advanced options:
# #
# # --report_mmatches — report query loci that match more than one catalog locus.
#
# ```
#
# This is how I would run it (below), except that my ustacks run failed and only 25% of my files went through, meaning a couple steps in my ustacks script had to be changed. So I did a couple parts manually, and at the terminal.
#
# ```
# !python pypipe_cstacks.py new_filenames_shell.txt ustacks_out 10 1 cstacks_out 3 5
# ```
#
# And then the output catalog files look like this:
#
# <br>
# ![image](https://github.com/nclowell/FISH546/blob/master/Cod-Time-Series-Project/Notebooks/images_for_notebooks/Screen%20Shot%202016-11-18%20at%202.25.06%20PM.png?raw=true)
# <br>

# %% [markdown]
# I ran ``ustacks`` on the remaining files overnight through the terminal, to not crash jupyter, and deleted all cstacks and sstacks files, to rerun them again on everything. This will be batch 2.

# %%
# !python pypipe_cstacks.py new_filenames_shell.txt ustacks_out 10 2 cstacks_out 3 5
# Out:
# cstacks paramters selected:
#   Loci matched based on sequence identity.
#   Number of mismatches allowed between stacks: 3
#   Gapped alignments: disabled
# Constructing catalog from 10 samples.
# Initializing new catalog...
#   Parsing ustacks_out/2015_101_1.tags.tsv.gz
#   Parsing ustacks_out/2015_101_1.snps.tsv.gz
#   Parsing ustacks_out/2015_101_1.alleles.tsv.gz
#   37987 loci were newly added to the catalog.
# Processing sample ustacks_out/2015_101_1 [2 of 10]
#   Parsing ustacks_out/2005_464_1.tags.tsv.gz
#   Parsing ustacks_out/2005_464_1.snps.tsv.gz
#   Parsing ustacks_out/2005_464_1.alleles.tsv.gz
# Searching for sequence matches...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
#   37987 loci in the catalog, 3925472 kmers in the catalog hash.
# Merging matches into catalog...
#   34143 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   4583 loci were newly added to the catalog.
#   185 loci matched more than one catalog locus and were excluded.
# Processing sample ustacks_out/2005_464_1 [3 of 10]
#   Parsing ustacks_out/2010_184_1.tags.tsv.gz
#   Parsing ustacks_out/2010_184_1.snps.tsv.gz
#   Parsing ustacks_out/2010_184_1.alleles.tsv.gz
# Searching for sequence matches...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
#   42570 loci in the catalog, 4336822 kmers in the catalog hash.
# Merging matches into catalog...
#   35970 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   2526 loci were newly added to the catalog.
#   167 loci matched more than one catalog locus and were excluded.
# Processing sample ustacks_out/2010_184_1 [4 of 10]
#   Parsing ustacks_out/2005_459_1.tags.tsv.gz
#   Parsing ustacks_out/2005_459_1.snps.tsv.gz
#   Parsing ustacks_out/2005_459_1.alleles.tsv.gz
# Searching for sequence matches...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
#   45096 loci in the catalog, 4541782 kmers in the catalog hash.
# Merging matches into catalog...
#   36655 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   1741 loci were newly added to the catalog.
#   198 loci matched more than one catalog locus and were excluded.
# Processing sample ustacks_out/2005_459_1 [5 of 10]
#   Parsing ustacks_out/2010_244_1.tags.tsv.gz
#   Parsing ustacks_out/2010_244_1.snps.tsv.gz
#   Parsing ustacks_out/2010_244_1.alleles.tsv.gz
# Searching for sequence matches...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
#   46837 loci in the catalog, 4691662 kmers in the catalog hash.
# Merging matches into catalog...
#   36145 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   2415 loci were newly added to the catalog.
#   179 loci matched more than one catalog locus and were excluded.
# Processing sample ustacks_out/2010_244_1 [6 of 10]
#   Parsing ustacks_out/2014_223_1.tags.tsv.gz
#   Parsing ustacks_out/2014_223_1.snps.tsv.gz
#   Parsing ustacks_out/2014_223_1.alleles.tsv.gz
# Searching for sequence matches...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
#   49252 loci in the catalog, 4913922 kmers in the catalog hash.
# Merging matches into catalog...
#   36470 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   1319 loci were newly added to the catalog.
#   181 loci matched more than one catalog locus and were excluded.
# Processing sample ustacks_out/2014_223_1 [7 of 10]
#  Unable to open 'ustacks_out/2014_174_1'
# Failed to load sample 7
# Processing sample ustacks_out/2014_174_1 [7 of 10]
#   Parsing ustacks_out/2010_266_1.tags.tsv.gz
#   Parsing ustacks_out/2010_266_1.snps.tsv.gz
#   Parsing ustacks_out/2010_266_1.alleles.tsv.gz
# Searching for sequence matches...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
#   50571 loci in the catalog, 5025064 kmers in the catalog hash.
# Merging matches into catalog...
#   34317 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   1455 loci were newly added to the catalog.
#   192 loci matched more than one catalog locus and were excluded.
# Processing sample ustacks_out/2010_266_1 [8 of 10]
#   Parsing ustacks_out/2015_103_1.tags.tsv.gz
#   Parsing ustacks_out/2015_103_1.snps.tsv.gz
#   Parsing ustacks_out/2015_103_1.alleles.tsv.gz
# Searching for sequence matches...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
#   52026 loci in the catalog, 5218537 kmers in the catalog hash.
# Merging matches into catalog...
#   36320 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   899 loci were newly added to the catalog.
#   157 loci matched more than one catalog locus and were excluded.
# Processing sample ustacks_out/2015_103_1 [9 of 10]
#   Parsing ustacks_out/2014_129_1.tags.tsv.gz
#   Parsing ustacks_out/2014_129_1.snps.tsv.gz
#   Parsing ustacks_out/2014_129_1.alleles.tsv.gz
# Searching for sequence matches...
#   Distance allowed between stacks: 3; searching with a k-mer length of 35 (110 k-mers per read); 5 k-mer hits required.
#   52925 loci in the catalog, 5294515 kmers in the catalog hash.
# Merging matches into catalog...
#   36843 loci were matched to a catalog locus.
#   0 loci were matched to a catalog locus using gapped alignments.
#   960 loci were newly added to the catalog.
#   167 loci matched more than one catalog locus and were excluded.
# Writing catalog to 'cstacks_out/... done.

# %% [markdown]
# ## ``sstacks``
#
# <br>
#
# Then comes sstacks, where the program matches each individuals reads to the catalog.
#
# My code looks like this:
#
# ```
# ##########################################################################################
# #
# ### ``sstacks``
# #
# # PURPOSE: To match individual samples against your catalog for genotyping
# # INPUT: TSV output files from cstacks
# # OUTPUT: match files
# #
# #
# ### WHEN RUNNING THIS SCRIPT, YOUR INPUTS AT THE COMMAND LINE ARE:
# # python
# # {0}[pipeline filename]
# # {1}[shell script w sample names]
# # {2}[batch ID number]
# # {3}[filepath to directory with catalog filename without file extension]
# # {4}[filepath to directory w ustacks output files per sample]
# # {5}[number of threads to use]
# #
# ### DEPENDENCIES
# #
# # [1]
# #
# ### WARNINGS
# #
# # [1]
# #
# ##########################################################################################
#
# # --- [A] call necessary modules
#
# import subprocess
# import sys
#
#
#
#
#
# # --- [B] make shell script for sstacks
#
# trim_names = [] # initiate list
#
# rename_shell = open(sys.argv[1], "r") # open file w filenames
# lines = rename_shell.readlines()[2:]
#
# for line in lines:
# 	linelist = line.strip().split()
# 	trim_name = linelist[2].rsplit(".",2)[0]
# 	trim_names.append(trim_name)
# # print trim_names # CHECK^
#
# rename_shell.close()
#
# numsamples = len(trim_names)
#
# newfile = open("sstacks_shell.txt", "w") # create new file for shell script
#
# filestring = ""
#
# for i in range(0,numsamples):
# 	filestring += "sstacks -b " + sys.argv[2] + " -c " + sys.argv[3]
# 	substr = " -s " + sys.argv[4] + "/" + trim_names[i] + " -p " + sys.argv[5] + "\n"
# 	filestring += substr
#
# # print filestring # ^CHECK
#
# newfile.write(filestring)
# newfile.close()
#
#
#
#
#
# # --- [C] run shell script for sstacks
#
# subprocess.call(["sh sstacks_shell.txt"], shell=True)
#
# ```
#
# Again, this run on "all" my data sort of failed when ustacks stopped overnight, so I'll need a new way of making a list of samples that I actually want to run sstacks on. Or, perhaps I can run it as is and it will skip those files and report that it couldn't find them. Let's try that...
#
# Later, on Nov 29-30 I reran ustacks on everything. So trying again, this will be batch 2.

# %%
# !python pypipe_sstacks.py new_filenames_shell.txt 2 ustacks_out/batch_1 ustacks_out 10 -o sstacks_out
# Out:
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_387_1' [1 of 1]
#   Parsing ustacks_out/2005_387_1.tags.tsv.gz
#   Parsing ustacks_out/2005_387_1.snps.tsv.gz
#   Parsing ustacks_out/2005_387_1.alleles.tsv.gz
# Searching for sequence matches...
# 20123 stacks compared against the catalog containing 61592 loci.
#   19776 matching loci, 1158 contained no verified haplotypes.
#   151 loci matched more than one catalog locus and were excluded.
#   1007 loci contained SNPs unaccounted for in the catalog and were excluded.
#   21083 total haplotypes examined from matching loci, 19679 verified.
# Outputing to file ./2005_387_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_387_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_387_2'
# Unable to parse 'ustacks_out/2005_387_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_388_1' [1 of 1]
#   Parsing ustacks_out/2005_388_1.tags.tsv.gz
#   Parsing ustacks_out/2005_388_1.snps.tsv.gz
#   Parsing ustacks_out/2005_388_1.alleles.tsv.gz
# Searching for sequence matches...
# 4452 stacks compared against the catalog containing 61592 loci.
#   4279 matching loci, 244 contained no verified haplotypes.
#   63 loci matched more than one catalog locus and were excluded.
#   181 loci contained SNPs unaccounted for in the catalog and were excluded.
#   4539 total haplotypes examined from matching loci, 4191 verified.
# Outputing to file ./2005_388_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_388_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_388_2'
# Unable to parse 'ustacks_out/2005_388_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_389_1' [1 of 1]
#   Parsing ustacks_out/2005_389_1.tags.tsv.gz
#   Parsing ustacks_out/2005_389_1.snps.tsv.gz
#   Parsing ustacks_out/2005_389_1.alleles.tsv.gz
# Searching for sequence matches...
# 22099 stacks compared against the catalog containing 61592 loci.
#   21727 matching loci, 1361 contained no verified haplotypes.
#   180 loci matched more than one catalog locus and were excluded.
#   1181 loci contained SNPs unaccounted for in the catalog and were excluded.
#   23369 total haplotypes examined from matching loci, 21695 verified.
# Outputing to file ./2005_389_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_389_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_389_2'
# Unable to parse 'ustacks_out/2005_389_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_457_1' [1 of 1]
#   Parsing ustacks_out/2005_457_1.tags.tsv.gz
#   Parsing ustacks_out/2005_457_1.snps.tsv.gz
#   Parsing ustacks_out/2005_457_1.alleles.tsv.gz
# Searching for sequence matches...
# 39269 stacks compared against the catalog containing 61592 loci.
#   38120 matching loci, 1112 contained no verified haplotypes.
#   155 loci matched more than one catalog locus and were excluded.
#   957 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42684 total haplotypes examined from matching loci, 41268 verified.
# Outputing to file ./2005_457_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_457_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_457_2'
# Unable to parse 'ustacks_out/2005_457_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2009_172_1' [1 of 1]
#   Parsing ustacks_out/2009_172_1.tags.tsv.gz
#   Parsing ustacks_out/2009_172_1.snps.tsv.gz
#   Parsing ustacks_out/2009_172_1.alleles.tsv.gz
# Searching for sequence matches...
# 1064 stacks compared against the catalog containing 61592 loci.
#   1010 matching loci, 58 contained no verified haplotypes.
#   30 loci matched more than one catalog locus and were excluded.
#   28 loci contained SNPs unaccounted for in the catalog and were excluded.
#   1085 total haplotypes examined from matching loci, 982 verified.
# Outputing to file ./2009_172_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2009_172_2' [1 of 1]
#  Unable to open 'ustacks_out/2009_172_2'
# Unable to parse 'ustacks_out/2009_172_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_114_1' [1 of 1]
#   Parsing ustacks_out/2010_114_1.tags.tsv.gz
#   Parsing ustacks_out/2010_114_1.snps.tsv.gz
#   Parsing ustacks_out/2010_114_1.alleles.tsv.gz
# Searching for sequence matches...
# 40170 stacks compared against the catalog containing 61592 loci.
#   40127 matching loci, 139 contained no verified haplotypes.
#   137 loci matched more than one catalog locus and were excluded.
#   2 loci contained SNPs unaccounted for in the catalog and were excluded.
#   46576 total haplotypes examined from matching loci, 46251 verified.
# Outputing to file ./2010_114_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_114_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_114_2'
# Unable to parse 'ustacks_out/2010_114_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_115_1' [1 of 1]
#   Parsing ustacks_out/2010_115_1.tags.tsv.gz
#   Parsing ustacks_out/2010_115_1.snps.tsv.gz
#   Parsing ustacks_out/2010_115_1.alleles.tsv.gz
# Searching for sequence matches...
# 39401 stacks compared against the catalog containing 61592 loci.
#   38070 matching loci, 1030 contained no verified haplotypes.
#   149 loci matched more than one catalog locus and were excluded.
#   881 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42533 total haplotypes examined from matching loci, 41196 verified.
# Outputing to file ./2010_115_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_115_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_115_2'
# Unable to parse 'ustacks_out/2010_115_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_116_1' [1 of 1]
#   Parsing ustacks_out/2010_116_1.tags.tsv.gz
#   Parsing ustacks_out/2010_116_1.snps.tsv.gz
#   Parsing ustacks_out/2010_116_1.alleles.tsv.gz
# Searching for sequence matches...
# 38810 stacks compared against the catalog containing 61592 loci.
#   37805 matching loci, 1020 contained no verified haplotypes.
#   145 loci matched more than one catalog locus and were excluded.
#   875 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42181 total haplotypes examined from matching loci, 40866 verified.
# Outputing to file ./2010_116_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_116_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_116_2'
# Unable to parse 'ustacks_out/2010_116_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_117_1' [1 of 1]
#   Parsing ustacks_out/2010_117_1.tags.tsv.gz
#   Parsing ustacks_out/2010_117_1.snps.tsv.gz
#   Parsing ustacks_out/2010_117_1.alleles.tsv.gz
# Searching for sequence matches...
# 40285 stacks compared against the catalog containing 61592 loci.
#   38839 matching loci, 1022 contained no verified haplotypes.
#   146 loci matched more than one catalog locus and were excluded.
#   876 loci contained SNPs unaccounted for in the catalog and were excluded.
#   43617 total haplotypes examined from matching loci, 42233 verified.
# Outputing to file ./2010_117_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_117_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_117_2'
# Unable to parse 'ustacks_out/2010_117_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_118_1' [1 of 1]
#   Parsing ustacks_out/2010_118_1.tags.tsv.gz
#   Parsing ustacks_out/2010_118_1.snps.tsv.gz
#   Parsing ustacks_out/2010_118_1.alleles.tsv.gz
# Searching for sequence matches...
# 40583 stacks compared against the catalog containing 61592 loci.
#   40532 matching loci, 129 contained no verified haplotypes.
#   128 loci matched more than one catalog locus and were excluded.
#   1 loci contained SNPs unaccounted for in the catalog and were excluded.
#   47031 total haplotypes examined from matching loci, 46712 verified.
# Outputing to file ./2010_118_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_118_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_118_2'
# Unable to parse 'ustacks_out/2010_118_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_119_1' [1 of 1]
#   Parsing ustacks_out/2010_119_1.tags.tsv.gz
#   Parsing ustacks_out/2010_119_1.snps.tsv.gz
#   Parsing ustacks_out/2010_119_1.alleles.tsv.gz
# Searching for sequence matches...
# 40080 stacks compared against the catalog containing 61592 loci.
#   38641 matching loci, 1085 contained no verified haplotypes.
#   138 loci matched more than one catalog locus and were excluded.
#   947 loci contained SNPs unaccounted for in the catalog and were excluded.
#   43336 total haplotypes examined from matching loci, 41921 verified.
# Outputing to file ./2010_119_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_119_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_119_2'
# Unable to parse 'ustacks_out/2010_119_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_123_1' [1 of 1]
#   Parsing ustacks_out/2010_123_1.tags.tsv.gz
#   Parsing ustacks_out/2010_123_1.snps.tsv.gz
#   Parsing ustacks_out/2010_123_1.alleles.tsv.gz
# Searching for sequence matches...
# 39593 stacks compared against the catalog containing 61592 loci.
#   38366 matching loci, 1070 contained no verified haplotypes.
#   140 loci matched more than one catalog locus and were excluded.
#   930 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42763 total haplotypes examined from matching loci, 41398 verified.
# Outputing to file ./2010_123_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_123_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_123_2'
# Unable to parse 'ustacks_out/2010_123_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_459_1' [1 of 1]
#   Parsing ustacks_out/2005_459_1.tags.tsv.gz
#   Parsing ustacks_out/2005_459_1.snps.tsv.gz
#   Parsing ustacks_out/2005_459_1.alleles.tsv.gz
# Searching for sequence matches...
# 38594 stacks compared against the catalog containing 61592 loci.
#   38550 matching loci, 122 contained no verified haplotypes.
#   119 loci matched more than one catalog locus and were excluded.
#   3 loci contained SNPs unaccounted for in the catalog and were excluded.
#   44212 total haplotypes examined from matching loci, 43932 verified.
# Outputing to file ./2005_459_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_459_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_459_2'
# Unable to parse 'ustacks_out/2005_459_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_462_1' [1 of 1]
#   Parsing ustacks_out/2005_462_1.tags.tsv.gz
#   Parsing ustacks_out/2005_462_1.snps.tsv.gz
#   Parsing ustacks_out/2005_462_1.alleles.tsv.gz
# Searching for sequence matches...
# 37319 stacks compared against the catalog containing 61592 loci.
#   37287 matching loci, 150 contained no verified haplotypes.
#   147 loci matched more than one catalog locus and were excluded.
#   3 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42668 total haplotypes examined from matching loci, 42321 verified.
# Outputing to file ./2005_462_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_462_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_462_2'
# Unable to parse 'ustacks_out/2005_462_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_463_1' [1 of 1]
#   Parsing ustacks_out/2005_463_1.tags.tsv.gz
#   Parsing ustacks_out/2005_463_1.snps.tsv.gz
#   Parsing ustacks_out/2005_463_1.alleles.tsv.gz
# Searching for sequence matches...
# 39641 stacks compared against the catalog containing 61592 loci.
#   38460 matching loci, 1073 contained no verified haplotypes.
#   125 loci matched more than one catalog locus and were excluded.
#   948 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42761 total haplotypes examined from matching loci, 41427 verified.
# Outputing to file ./2005_463_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_463_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_463_2'
# Unable to parse 'ustacks_out/2005_463_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_464_1' [1 of 1]
#   Parsing ustacks_out/2005_464_1.tags.tsv.gz
#   Parsing ustacks_out/2005_464_1.snps.tsv.gz
#   Parsing ustacks_out/2005_464_1.alleles.tsv.gz
# Searching for sequence matches...
# 38911 stacks compared against the catalog containing 61592 loci.
#   38911 matching loci, 18 contained no verified haplotypes.
#   18 loci matched more than one catalog locus and were excluded.
#   0 loci contained SNPs unaccounted for in the catalog and were excluded.
#   44730 total haplotypes examined from matching loci, 44685 verified.
# Outputing to file ./2005_464_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_464_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_464_2'
# Unable to parse 'ustacks_out/2005_464_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2009_173_1' [1 of 1]
#   Parsing ustacks_out/2009_173_1.tags.tsv.gz
#   Parsing ustacks_out/2009_173_1.snps.tsv.gz
#   Parsing ustacks_out/2009_173_1.alleles.tsv.gz
# Searching for sequence matches...
# 3761 stacks compared against the catalog containing 61592 loci.
#   3586 matching loci, 221 contained no verified haplotypes.
#   64 loci matched more than one catalog locus and were excluded.
#   157 loci contained SNPs unaccounted for in the catalog and were excluded.
#   3826 total haplotypes examined from matching loci, 3505 verified.
# Outputing to file ./2009_173_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2009_173_2' [1 of 1]
#  Unable to open 'ustacks_out/2009_173_2'
# Unable to parse 'ustacks_out/2009_173_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_127_1' [1 of 1]
#   Parsing ustacks_out/2010_127_1.tags.tsv.gz
#   Parsing ustacks_out/2010_127_1.snps.tsv.gz
#   Parsing ustacks_out/2010_127_1.alleles.tsv.gz
# Searching for sequence matches...
# 40481 stacks compared against the catalog containing 61592 loci.
#   40436 matching loci, 134 contained no verified haplotypes.
#   132 loci matched more than one catalog locus and were excluded.
#   2 loci contained SNPs unaccounted for in the catalog and were excluded.
#   47095 total haplotypes examined from matching loci, 46788 verified.
# Outputing to file ./2010_127_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_127_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_127_2'
# Unable to parse 'ustacks_out/2010_127_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_184_1' [1 of 1]
#   Parsing ustacks_out/2010_184_1.tags.tsv.gz
#   Parsing ustacks_out/2010_184_1.snps.tsv.gz
#   Parsing ustacks_out/2010_184_1.alleles.tsv.gz
# Searching for sequence matches...
# 38663 stacks compared against the catalog containing 61592 loci.
#   38642 matching loci, 105 contained no verified haplotypes.
#   98 loci matched more than one catalog locus and were excluded.
#   7 loci contained SNPs unaccounted for in the catalog and were excluded.
#   44194 total haplotypes examined from matching loci, 43953 verified.
# Outputing to file ./2010_184_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_184_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_184_2'
# Unable to parse 'ustacks_out/2010_184_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_185_1' [1 of 1]
#   Parsing ustacks_out/2010_185_1.tags.tsv.gz
#   Parsing ustacks_out/2010_185_1.snps.tsv.gz
#   Parsing ustacks_out/2010_185_1.alleles.tsv.gz
# Searching for sequence matches...
# 40010 stacks compared against the catalog containing 61592 loci.
#   38616 matching loci, 1152 contained no verified haplotypes.
#   133 loci matched more than one catalog locus and were excluded.
#   1019 loci contained SNPs unaccounted for in the catalog and were excluded.
#   43092 total haplotypes examined from matching loci, 41627 verified.
# Outputing to file ./2010_185_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_185_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_185_2'
# Unable to parse 'ustacks_out/2010_185_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_187_1' [1 of 1]
#   Parsing ustacks_out/2010_187_1.tags.tsv.gz
#   Parsing ustacks_out/2010_187_1.snps.tsv.gz
#   Parsing ustacks_out/2010_187_1.alleles.tsv.gz
# Searching for sequence matches...
# 39772 stacks compared against the catalog containing 61592 loci.
#   38612 matching loci, 1051 contained no verified haplotypes.
#   142 loci matched more than one catalog locus and were excluded.
#   909 loci contained SNPs unaccounted for in the catalog and were excluded.
#   43260 total haplotypes examined from matching loci, 41881 verified.
# Outputing to file ./2010_187_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_187_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_187_2'
# Unable to parse 'ustacks_out/2010_187_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_188_1' [1 of 1]
#   Parsing ustacks_out/2010_188_1.tags.tsv.gz
#   Parsing ustacks_out/2010_188_1.snps.tsv.gz
#   Parsing ustacks_out/2010_188_1.alleles.tsv.gz
# Searching for sequence matches...
# 40324 stacks compared against the catalog containing 61592 loci.
#   38960 matching loci, 1106 contained no verified haplotypes.
#   145 loci matched more than one catalog locus and were excluded.
#   961 loci contained SNPs unaccounted for in the catalog and were excluded.
#   43562 total haplotypes examined from matching loci, 42131 verified.
# Outputing to file ./2010_188_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_188_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_188_2'
# Unable to parse 'ustacks_out/2010_188_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_189_1' [1 of 1]
#   Parsing ustacks_out/2010_189_1.tags.tsv.gz
#   Parsing ustacks_out/2010_189_1.snps.tsv.gz
#   Parsing ustacks_out/2010_189_1.alleles.tsv.gz
# Searching for sequence matches...
# 40315 stacks compared against the catalog containing 61592 loci.
#   40280 matching loci, 149 contained no verified haplotypes.
#   149 loci matched more than one catalog locus and were excluded.
#   0 loci contained SNPs unaccounted for in the catalog and were excluded.
#   46684 total haplotypes examined from matching loci, 46319 verified.
# Outputing to file ./2010_189_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_189_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_189_2'
# Unable to parse 'ustacks_out/2010_189_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_211_1' [1 of 1]
#   Parsing ustacks_out/2010_211_1.tags.tsv.gz
#   Parsing ustacks_out/2010_211_1.snps.tsv.gz
#   Parsing ustacks_out/2010_211_1.alleles.tsv.gz
# Searching for sequence matches...
# 40187 stacks compared against the catalog containing 61592 loci.
#   38847 matching loci, 1117 contained no verified haplotypes.
#   145 loci matched more than one catalog locus and were excluded.
#   972 loci contained SNPs unaccounted for in the catalog and were excluded.
#   43613 total haplotypes examined from matching loci, 42146 verified.
# Outputing to file ./2010_211_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_211_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_211_2'
# Unable to parse 'ustacks_out/2010_211_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_465_1' [1 of 1]
#   Parsing ustacks_out/2005_465_1.tags.tsv.gz
#   Parsing ustacks_out/2005_465_1.snps.tsv.gz
#   Parsing ustacks_out/2005_465_1.alleles.tsv.gz
# Searching for sequence matches...
# 43179 stacks compared against the catalog containing 61592 loci.
#   43024 matching loci, 103 contained no verified haplotypes.
#   83 loci matched more than one catalog locus and were excluded.
#   20 loci contained SNPs unaccounted for in the catalog and were excluded.
#   51410 total haplotypes examined from matching loci, 51178 verified.
# Outputing to file ./2005_465_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_465_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_465_2'
# Unable to parse 'ustacks_out/2005_465_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_466_1' [1 of 1]
#   Parsing ustacks_out/2005_466_1.tags.tsv.gz
#   Parsing ustacks_out/2005_466_1.snps.tsv.gz
#   Parsing ustacks_out/2005_466_1.alleles.tsv.gz
# Searching for sequence matches...
# 43736 stacks compared against the catalog containing 61592 loci.
#   43551 matching loci, 107 contained no verified haplotypes.
#   78 loci matched more than one catalog locus and were excluded.
#   29 loci contained SNPs unaccounted for in the catalog and were excluded.
#   53531 total haplotypes examined from matching loci, 53316 verified.
# Outputing to file ./2005_466_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_466_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_466_2'
# Unable to parse 'ustacks_out/2005_466_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_467_1' [1 of 1]
#   Parsing ustacks_out/2005_467_1.tags.tsv.gz
#   Parsing ustacks_out/2005_467_1.snps.tsv.gz
#   Parsing ustacks_out/2005_467_1.alleles.tsv.gz
# Searching for sequence matches...
# 40113 stacks compared against the catalog containing 61592 loci.
#   38575 matching loci, 1231 contained no verified haplotypes.
#   124 loci matched more than one catalog locus and were excluded.
#   1107 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42819 total haplotypes examined from matching loci, 41277 verified.
# Outputing to file ./2005_467_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_467_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_467_2'
# Unable to parse 'ustacks_out/2005_467_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_495_1' [1 of 1]
#   Parsing ustacks_out/2005_495_1.tags.tsv.gz
#   Parsing ustacks_out/2005_495_1.snps.tsv.gz
#   Parsing ustacks_out/2005_495_1.alleles.tsv.gz
# Searching for sequence matches...
# 39374 stacks compared against the catalog containing 61592 loci.
#   38064 matching loci, 1233 contained no verified haplotypes.
#   127 loci matched more than one catalog locus and were excluded.
#   1106 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42234 total haplotypes examined from matching loci, 40710 verified.
# Outputing to file ./2005_495_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_495_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_495_2'
# Unable to parse 'ustacks_out/2005_495_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2009_176_1' [1 of 1]
#   Parsing ustacks_out/2009_176_1.tags.tsv.gz
#   Parsing ustacks_out/2009_176_1.snps.tsv.gz
#   Parsing ustacks_out/2009_176_1.alleles.tsv.gz
# Searching for sequence matches...
# 33208 stacks compared against the catalog containing 61592 loci.
#   32281 matching loci, 2157 contained no verified haplotypes.
#   119 loci matched more than one catalog locus and were excluded.
#   2038 loci contained SNPs unaccounted for in the catalog and were excluded.
#   34966 total haplotypes examined from matching loci, 32551 verified.
# Outputing to file ./2009_176_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2009_176_2' [1 of 1]
#  Unable to open 'ustacks_out/2009_176_2'
# Unable to parse 'ustacks_out/2009_176_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_212_1' [1 of 1]
#   Parsing ustacks_out/2010_212_1.tags.tsv.gz
#   Parsing ustacks_out/2010_212_1.snps.tsv.gz
#   Parsing ustacks_out/2010_212_1.alleles.tsv.gz
# Searching for sequence matches...
# 41885 stacks compared against the catalog containing 61592 loci.
#   39631 matching loci, 1132 contained no verified haplotypes.
#   112 loci matched more than one catalog locus and were excluded.
#   1020 loci contained SNPs unaccounted for in the catalog and were excluded.
#   44421 total haplotypes examined from matching loci, 42943 verified.
# Outputing to file ./2010_212_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_212_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_212_2'
# Unable to parse 'ustacks_out/2010_212_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_213_1' [1 of 1]
#   Parsing ustacks_out/2010_213_1.tags.tsv.gz
#   Parsing ustacks_out/2010_213_1.snps.tsv.gz
#   Parsing ustacks_out/2010_213_1.alleles.tsv.gz
# Searching for sequence matches...
# 42132 stacks compared against the catalog containing 61592 loci.
#   39706 matching loci, 1189 contained no verified haplotypes.
#   135 loci matched more than one catalog locus and were excluded.
#   1054 loci contained SNPs unaccounted for in the catalog and were excluded.
#   44269 total haplotypes examined from matching loci, 42654 verified.
# Outputing to file ./2010_213_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_213_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_213_2'
# Unable to parse 'ustacks_out/2010_213_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_215_1' [1 of 1]
#   Parsing ustacks_out/2010_215_1.tags.tsv.gz
#   Parsing ustacks_out/2010_215_1.snps.tsv.gz
#   Parsing ustacks_out/2010_215_1.alleles.tsv.gz
# Searching for sequence matches...
# 41141 stacks compared against the catalog containing 61592 loci.
#   39334 matching loci, 1171 contained no verified haplotypes.
#   131 loci matched more than one catalog locus and were excluded.
#   1040 loci contained SNPs unaccounted for in the catalog and were excluded.
#   43808 total haplotypes examined from matching loci, 42323 verified.
# Outputing to file ./2010_215_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_215_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_215_2'
# Unable to parse 'ustacks_out/2010_215_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_216_1' [1 of 1]
#   Parsing ustacks_out/2010_216_1.tags.tsv.gz
#   Parsing ustacks_out/2010_216_1.snps.tsv.gz
#   Parsing ustacks_out/2010_216_1.alleles.tsv.gz
# Searching for sequence matches...
# 40940 stacks compared against the catalog containing 61592 loci.
#   39086 matching loci, 1144 contained no verified haplotypes.
#   130 loci matched more than one catalog locus and were excluded.
#   1014 loci contained SNPs unaccounted for in the catalog and were excluded.
#   43523 total haplotypes examined from matching loci, 42044 verified.
# Outputing to file ./2010_216_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_216_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_216_2'
# Unable to parse 'ustacks_out/2010_216_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_218_1' [1 of 1]
#   Parsing ustacks_out/2010_218_1.tags.tsv.gz
#   Parsing ustacks_out/2010_218_1.snps.tsv.gz
#   Parsing ustacks_out/2010_218_1.alleles.tsv.gz
# Searching for sequence matches...
# 40329 stacks compared against the catalog containing 61592 loci.
#   38347 matching loci, 1089 contained no verified haplotypes.
#   137 loci matched more than one catalog locus and were excluded.
#   952 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42664 total haplotypes examined from matching loci, 41285 verified.
# Outputing to file ./2010_218_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_218_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_218_2'
# Unable to parse 'ustacks_out/2010_218_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_219_1' [1 of 1]
#   Parsing ustacks_out/2010_219_1.tags.tsv.gz
#   Parsing ustacks_out/2010_219_1.snps.tsv.gz
#   Parsing ustacks_out/2010_219_1.alleles.tsv.gz
# Searching for sequence matches...
# 48278 stacks compared against the catalog containing 61592 loci.
#   39743 matching loci, 1135 contained no verified haplotypes.
#   132 loci matched more than one catalog locus and were excluded.
#   1003 loci contained SNPs unaccounted for in the catalog and were excluded.
#   44438 total haplotypes examined from matching loci, 42893 verified.
# Outputing to file ./2010_219_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_219_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_219_2'
# Unable to parse 'ustacks_out/2010_219_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_220_1' [1 of 1]
#   Parsing ustacks_out/2010_220_1.tags.tsv.gz
#   Parsing ustacks_out/2010_220_1.snps.tsv.gz
#   Parsing ustacks_out/2010_220_1.alleles.tsv.gz
# Searching for sequence matches...
# 43243 stacks compared against the catalog containing 61592 loci.
#   40010 matching loci, 1238 contained no verified haplotypes.
#   128 loci matched more than one catalog locus and were excluded.
#   1110 loci contained SNPs unaccounted for in the catalog and were excluded.
#   44586 total haplotypes examined from matching loci, 42939 verified.
# Outputing to file ./2010_220_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_220_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_220_2'
# Unable to parse 'ustacks_out/2010_220_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_559_1' [1 of 1]
#   Parsing ustacks_out/2005_559_1.tags.tsv.gz
#   Parsing ustacks_out/2005_559_1.snps.tsv.gz
#   Parsing ustacks_out/2005_559_1.alleles.tsv.gz
# Searching for sequence matches...
# 38614 stacks compared against the catalog containing 61592 loci.
#   37243 matching loci, 1202 contained no verified haplotypes.
#   143 loci matched more than one catalog locus and were excluded.
#   1059 loci contained SNPs unaccounted for in the catalog and were excluded.
#   41171 total haplotypes examined from matching loci, 39646 verified.
# Outputing to file ./2005_559_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_559_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_559_2'
# Unable to parse 'ustacks_out/2005_559_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_297_1' [1 of 1]
#   Parsing ustacks_out/2005_297_1.tags.tsv.gz
#   Parsing ustacks_out/2005_297_1.snps.tsv.gz
#   Parsing ustacks_out/2005_297_1.alleles.tsv.gz
# Searching for sequence matches...
# 34567 stacks compared against the catalog containing 61592 loci.
#   32788 matching loci, 2881 contained no verified haplotypes.
#   133 loci matched more than one catalog locus and were excluded.
#   2748 loci contained SNPs unaccounted for in the catalog and were excluded.
#   35427 total haplotypes examined from matching loci, 32211 verified.
# Outputing to file ./2005_297_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_297_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_297_2'
# Unable to parse 'ustacks_out/2005_297_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_298_1' [1 of 1]
#   Parsing ustacks_out/2005_298_1.tags.tsv.gz
#   Parsing ustacks_out/2005_298_1.snps.tsv.gz
#   Parsing ustacks_out/2005_298_1.alleles.tsv.gz
# Searching for sequence matches...
# 37751 stacks compared against the catalog containing 61592 loci.
#   35941 matching loci, 1895 contained no verified haplotypes.
#   125 loci matched more than one catalog locus and were excluded.
#   1770 loci contained SNPs unaccounted for in the catalog and were excluded.
#   39375 total haplotypes examined from matching loci, 37190 verified.
# Outputing to file ./2005_298_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2005_298_2' [1 of 1]
#  Unable to open 'ustacks_out/2005_298_2'
# Unable to parse 'ustacks_out/2005_298_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2009_171_1' [1 of 1]
#   Parsing ustacks_out/2009_171_1.tags.tsv.gz
#   Parsing ustacks_out/2009_171_1.snps.tsv.gz
#   Parsing ustacks_out/2009_171_1.alleles.tsv.gz
# Searching for sequence matches...
# 12577 stacks compared against the catalog containing 61592 loci.
#   12006 matching loci, 959 contained no verified haplotypes.
#   92 loci matched more than one catalog locus and were excluded.
#   867 loci contained SNPs unaccounted for in the catalog and were excluded.
#   12610 total haplotypes examined from matching loci, 11494 verified.
# Outputing to file ./2009_171_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2009_171_2' [1 of 1]
#  Unable to open 'ustacks_out/2009_171_2'
# Unable to parse 'ustacks_out/2009_171_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_221_1' [1 of 1]
#   Parsing ustacks_out/2010_221_1.tags.tsv.gz
#   Parsing ustacks_out/2010_221_1.snps.tsv.gz
#   Parsing ustacks_out/2010_221_1.alleles.tsv.gz
# Searching for sequence matches...
# 39958 stacks compared against the catalog containing 61592 loci.
#   38014 matching loci, 1145 contained no verified haplotypes.
#   135 loci matched more than one catalog locus and were excluded.
#   1010 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42245 total haplotypes examined from matching loci, 40749 verified.
# Outputing to file ./2010_221_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_221_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_221_2'
# Unable to parse 'ustacks_out/2010_221_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_222_1' [1 of 1]
#   Parsing ustacks_out/2010_222_1.tags.tsv.gz
#   Parsing ustacks_out/2010_222_1.snps.tsv.gz
#   Parsing ustacks_out/2010_222_1.alleles.tsv.gz
# Searching for sequence matches...
# 41266 stacks compared against the catalog containing 61592 loci.
#   38511 matching loci, 1140 contained no verified haplotypes.
#   106 loci matched more than one catalog locus and were excluded.
#   1034 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42754 total haplotypes examined from matching loci, 41306 verified.
# Outputing to file ./2010_222_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2010_222_2' [1 of 1]
#  Unable to open 'ustacks_out/2010_222_2'
# Unable to parse 'ustacks_out/2010_222_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
# ...
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_139_1' [1 of 1]
#   Parsing ustacks_out/2015_139_1.tags.tsv.gz
#   Parsing ustacks_out/2015_139_1.snps.tsv.gz
#   Parsing ustacks_out/2015_139_1.alleles.tsv.gz
# Searching for sequence matches...
# 38137 stacks compared against the catalog containing 61592 loci.
#   36883 matching loci, 1214 contained no verified haplotypes.
#   158 loci matched more than one catalog locus and were excluded.
#   1056 loci contained SNPs unaccounted for in the catalog and were excluded.
#   40747 total haplotypes examined from matching loci, 39224 verified.
# Outputing to file ./2015_139_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_139_2' [1 of 1]
#  Unable to open 'ustacks_out/2015_139_2'
# Unable to parse 'ustacks_out/2015_139_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_140_1' [1 of 1]
#   Parsing ustacks_out/2015_140_1.tags.tsv.gz
#   Parsing ustacks_out/2015_140_1.snps.tsv.gz
#   Parsing ustacks_out/2015_140_1.alleles.tsv.gz
# Searching for sequence matches...
# 37507 stacks compared against the catalog containing 61592 loci.
#   36275 matching loci, 1156 contained no verified haplotypes.
#   132 loci matched more than one catalog locus and were excluded.
#   1024 loci contained SNPs unaccounted for in the catalog and were excluded.
#   39974 total haplotypes examined from matching loci, 38593 verified.
# Outputing to file ./2015_140_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_140_2' [1 of 1]
#  Unable to open 'ustacks_out/2015_140_2'
# Unable to parse 'ustacks_out/2015_140_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_141_1' [1 of 1]
#   Parsing ustacks_out/2015_141_1.tags.tsv.gz
#   Parsing ustacks_out/2015_141_1.snps.tsv.gz
#   Parsing ustacks_out/2015_141_1.alleles.tsv.gz
# Searching for sequence matches...
# 37501 stacks compared against the catalog containing 61592 loci.
#   36181 matching loci, 1175 contained no verified haplotypes.
#   133 loci matched more than one catalog locus and were excluded.
#   1042 loci contained SNPs unaccounted for in the catalog and were excluded.
#   39788 total haplotypes examined from matching loci, 38380 verified.
# Outputing to file ./2015_141_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_141_2' [1 of 1]
#  Unable to open 'ustacks_out/2015_141_2'
# Unable to parse 'ustacks_out/2015_141_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_232_1' [1 of 1]
#   Parsing ustacks_out/2014_232_1.tags.tsv.gz
#   Parsing ustacks_out/2014_232_1.snps.tsv.gz
#   Parsing ustacks_out/2014_232_1.alleles.tsv.gz
# Searching for sequence matches...
# 38331 stacks compared against the catalog containing 61592 loci.
#   37079 matching loci, 1182 contained no verified haplotypes.
#   147 loci matched more than one catalog locus and were excluded.
#   1035 loci contained SNPs unaccounted for in the catalog and were excluded.
#   41199 total haplotypes examined from matching loci, 39695 verified.
# Outputing to file ./2014_232_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_232_2' [1 of 1]
#  Unable to open 'ustacks_out/2014_232_2'
# Unable to parse 'ustacks_out/2014_232_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_208_1' [1 of 1]
#   Parsing ustacks_out/2014_208_1.tags.tsv.gz
#   Parsing ustacks_out/2014_208_1.snps.tsv.gz
#   Parsing ustacks_out/2014_208_1.alleles.tsv.gz
# Searching for sequence matches...
# 37327 stacks compared against the catalog containing 61592 loci.
#   36188 matching loci, 1150 contained no verified haplotypes.
#   154 loci matched more than one catalog locus and were excluded.
#   996 loci contained SNPs unaccounted for in the catalog and were excluded.
#   40113 total haplotypes examined from matching loci, 38698 verified.
# Outputing to file ./2014_208_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_208_2' [1 of 1]
#  Unable to open 'ustacks_out/2014_208_2'
# Unable to parse 'ustacks_out/2014_208_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_218_1' [1 of 1]
#   Parsing ustacks_out/2014_218_1.tags.tsv.gz
#   Parsing ustacks_out/2014_218_1.snps.tsv.gz
#   Parsing ustacks_out/2014_218_1.alleles.tsv.gz
# Searching for sequence matches...
# 36435 stacks compared against the catalog containing 61592 loci.
#   35429 matching loci, 1212 contained no verified haplotypes.
#   145 loci matched more than one catalog locus and were excluded.
#   1067 loci contained SNPs unaccounted for in the catalog and were excluded.
#   39121 total haplotypes examined from matching loci, 37670 verified.
# Outputing to file ./2014_218_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_218_2' [1 of 1]
#  Unable to open 'ustacks_out/2014_218_2'
# Unable to parse 'ustacks_out/2014_218_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_223_1' [1 of 1]
#   Parsing ustacks_out/2014_223_1.tags.tsv.gz
#   Parsing ustacks_out/2014_223_1.snps.tsv.gz
#   Parsing ustacks_out/2014_223_1.alleles.tsv.gz
# Searching for sequence matches...
# 37970 stacks compared against the catalog containing 61592 loci.
#   36891 matching loci, 1017 contained no verified haplotypes.
#   138 loci matched more than one catalog locus and were excluded.
#   879 loci contained SNPs unaccounted for in the catalog and were excluded.
#   41029 total haplotypes examined from matching loci, 39708 verified.
# Outputing to file ./2014_223_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_223_2' [1 of 1]
#  Unable to open 'ustacks_out/2014_223_2'
# Unable to parse 'ustacks_out/2014_223_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_224_1' [1 of 1]
#   Parsing ustacks_out/2014_224_1.tags.tsv.gz
#   Parsing ustacks_out/2014_224_1.snps.tsv.gz
#   Parsing ustacks_out/2014_224_1.alleles.tsv.gz
# Searching for sequence matches...
# 34952 stacks compared against the catalog containing 61592 loci.
#   34085 matching loci, 1097 contained no verified haplotypes.
#   146 loci matched more than one catalog locus and were excluded.
#   951 loci contained SNPs unaccounted for in the catalog and were excluded.
#   37320 total haplotypes examined from matching loci, 35986 verified.
# Outputing to file ./2014_224_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_224_2' [1 of 1]
#  Unable to open 'ustacks_out/2014_224_2'
# Unable to parse 'ustacks_out/2014_224_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_103_1' [1 of 1]
#   Parsing ustacks_out/2015_103_1.tags.tsv.gz
#   Parsing ustacks_out/2015_103_1.snps.tsv.gz
#   Parsing ustacks_out/2015_103_1.alleles.tsv.gz
# Searching for sequence matches...
# 37376 stacks compared against the catalog containing 61592 loci.
#   36495 matching loci, 961 contained no verified haplotypes.
#   152 loci matched more than one catalog locus and were excluded.
#   809 loci contained SNPs unaccounted for in the catalog and were excluded.
#   40446 total haplotypes examined from matching loci, 39228 verified.
# Outputing to file ./2015_103_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_103_2' [1 of 1]
#  Unable to open 'ustacks_out/2015_103_2'
# Unable to parse 'ustacks_out/2015_103_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_105_1' [1 of 1]
#   Parsing ustacks_out/2015_105_1.tags.tsv.gz
#   Parsing ustacks_out/2015_105_1.snps.tsv.gz
#   Parsing ustacks_out/2015_105_1.alleles.tsv.gz
# Searching for sequence matches...
# 38791 stacks compared against the catalog containing 61592 loci.
#   37311 matching loci, 1019 contained no verified haplotypes.
#   127 loci matched more than one catalog locus and were excluded.
#   892 loci contained SNPs unaccounted for in the catalog and were excluded.
#   41457 total haplotypes examined from matching loci, 40176 verified.
# Outputing to file ./2015_105_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_105_2' [1 of 1]
#  Unable to open 'ustacks_out/2015_105_2'
# Unable to parse 'ustacks_out/2015_105_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_138_1' [1 of 1]
#   Parsing ustacks_out/2015_138_1.tags.tsv.gz
#   Parsing ustacks_out/2015_138_1.snps.tsv.gz
#   Parsing ustacks_out/2015_138_1.alleles.tsv.gz
# Searching for sequence matches...
# 36841 stacks compared against the catalog containing 61592 loci.
#   35730 matching loci, 1189 contained no verified haplotypes.
#   138 loci matched more than one catalog locus and were excluded.
#   1051 loci contained SNPs unaccounted for in the catalog and were excluded.
#   39381 total haplotypes examined from matching loci, 37949 verified.
# Outputing to file ./2015_138_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2015_138_2' [1 of 1]
#  Unable to open 'ustacks_out/2015_138_2'
# Unable to parse 'ustacks_out/2015_138_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_128_1' [1 of 1]
#   Parsing ustacks_out/2014_128_1.tags.tsv.gz
#   Parsing ustacks_out/2014_128_1.snps.tsv.gz
#   Parsing ustacks_out/2014_128_1.alleles.tsv.gz
# Searching for sequence matches...
# 39595 stacks compared against the catalog containing 61592 loci.
#   38224 matching loci, 1046 contained no verified haplotypes.
#   144 loci matched more than one catalog locus and were excluded.
#   902 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42825 total haplotypes examined from matching loci, 41472 verified.
# Outputing to file ./2014_128_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_128_2' [1 of 1]
#  Unable to open 'ustacks_out/2014_128_2'
# Unable to parse 'ustacks_out/2014_128_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_129_1' [1 of 1]
#   Parsing ustacks_out/2014_129_1.tags.tsv.gz
#   Parsing ustacks_out/2014_129_1.snps.tsv.gz
#   Parsing ustacks_out/2014_129_1.alleles.tsv.gz
# Searching for sequence matches...
# 37970 stacks compared against the catalog containing 61592 loci.
#   36919 matching loci, 1006 contained no verified haplotypes.
#   144 loci matched more than one catalog locus and were excluded.
#   862 loci contained SNPs unaccounted for in the catalog and were excluded.
#   40989 total haplotypes examined from matching loci, 39690 verified.
# Outputing to file ./2014_129_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_129_2' [1 of 1]
#  Unable to open 'ustacks_out/2014_129_2'
# Unable to parse 'ustacks_out/2014_129_2'
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_130_1' [1 of 1]
#   Parsing ustacks_out/2014_130_1.tags.tsv.gz
#   Parsing ustacks_out/2014_130_1.snps.tsv.gz
#   Parsing ustacks_out/2014_130_1.alleles.tsv.gz
# Searching for sequence matches...
# 39457 stacks compared against the catalog containing 61592 loci.
#   37910 matching loci, 1079 contained no verified haplotypes.
#   125 loci matched more than one catalog locus and were excluded.
#   954 loci contained SNPs unaccounted for in the catalog and were excluded.
#   42287 total haplotypes examined from matching loci, 40930 verified.
# Outputing to file ./2014_130_1.matches.tsv.gz
# Searching for matches by sequence identity...
#   Parsing ustacks_out/batch_1.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_1.catalog.alleles.tsv.gz
# Processing sample 'ustacks_out/2014_130_2' [1 of 1]
#  Unable to open 'ustacks_out/2014_130_2'
# Unable to parse 'ustacks_out/2014_130_2'

# %% [markdown]
# So now I have:
#
# <br>
# ![image](https://github.com/nclowell/FISH546/blob/master/Cod-Time-Series-Project/Notebooks/images_for_notebooks/Screen%20Shot%202016-11-18%20at%203.05.39%20PM.png?raw=true)
#
# <br>
#
# ## ``populations``
#
# Then populations! I also just learned that my ``ustacks`` and ``sstacks`` files need to be in the same directory, so I manually moved those.
#
# Then I run ``populations`` like this:

# %%
# !populations -b 2 -P ustacks_out -M popmap1.txt -t 10 -r 0.50 -p 2 -m 5 --genepop
# Out:
# Fst kernel smoothing: off
# Bootstrap resampling: off
# Percent samples limit per population: 0.5
# Locus Population limit: 2
# Minimum stack depth: 5
# Log liklihood filtering: off; threshold: 0
# Minor allele frequency cutoff: 0
# Maximum observed heterozygosity cutoff: 1
# Applying Fst correction: none.
# Parsing population map...
# The population map contained 26 samples, 3 population(s), 1 group(s).
# Reading the catalog...
#   Parsing ustacks_out/batch_2.catalog.tags.tsv.gz
#   Parsing ustacks_out/batch_2.catalog.snps.tsv.gz
#   Parsing ustacks_out/batch_2.catalog.alleles.tsv.gz
# Reading matches to the catalog...
#   Parsing ustacks_out/2005_387_1.matches.tsv.gz
#   Parsing ustacks_out/2005_388_1.matches.tsv.gz
#   Parsing ustacks_out/2005_389_1.matches.tsv.gz
#   Parsing ustacks_out/2005_457_1.matches.tsv.gz
#   Parsing ustacks_out/2005_459_1.matches.tsv.gz
#   Parsing ustacks_out/2005_462_1.matches.tsv.gz
#   Parsing ustacks_out/2005_463_1.matches.tsv.gz
#   Parsing ustacks_out/2005_464_1.matches.tsv.gz
#   Parsing ustacks_out/2005_465_1.matches.tsv.gz
#   Parsing ustacks_out/2005_466_1.matches.tsv.gz
#   Parsing ustacks_out/2009_172_1.matches.tsv.gz
#   Parsing ustacks_out/2009_173_1.matches.tsv.gz
# Warning: Absent or malformed matches file '12010_85_1.matches.tsv(.gz)', excluding this sample from population analysis.
#   Parsing ustacks_out/2010_114_1.matches.tsv.gz
#   Parsing ustacks_out/2010_115_1.matches.tsv.gz
#   Parsing ustacks_out/2010_116_1.matches.tsv.gz
#   Parsing ustacks_out/2010_117_1.matches.tsv.gz
#   Parsing ustacks_out/2010_118_1.matches.tsv.gz
#   Parsing ustacks_out/2010_119_1.matches.tsv.gz
#   Parsing ustacks_out/2010_123_1.matches.tsv.gz
#   Parsing ustacks_out/2010_127_1.matches.tsv.gz
#   Parsing ustacks_out/2010_184_1.matches.tsv.gz
#   Parsing ustacks_out/2010_187_1.matches.tsv.gz
#   Parsing ustacks_out/2010_188_1.matches.tsv.gz
#   Parsing ustacks_out/2010_189_1.matches.tsv.gz
#   Parsing ustacks_out/2010_211_1.matches.tsv.gz
# Catalog is not reference aligned, arbitrarily ordering catalog loci.
# Working on 25 samples.
# Working on 3 population(s):
#     2005: 2005_387_1, 2005_388_1, 2005_389_1, 2005_457_1, 2005_459_1, 2005_462_1, 2005_463_1, 2005_464_1, 2005_465_1, 2005_466_1
#     2009: 2009_172_1, 2009_173_1
#     2010: 2010_114_1, 2010_115_1, 2010_116_1, 2010_117_1, 2010_118_1, 2010_119_1, 2010_123_1, 2010_127_1, 2010_184_1, 2010_187_1, 2010_188_1, 2010_189_1, 2010_211_1
# Working on 1 group(s) of populations:
#     defaultgrp: 2005, 2009, 2010
# Populating observed haplotypes for 25 samples, 53885 loci.
# Removed 16 samples from loci that are below the minimum stack depth of 5x
# Removing 19061 loci that did not pass sample/population constraints... retained 34824 loci.
# Loading model outputs for 25 samples, 34824 loci.
#   Parsing ustacks_out/2005_387_1.models.tsv.gz
#   Parsing ustacks_out/2005_388_1.models.tsv.gz
#   Parsing ustacks_out/2005_389_1.models.tsv.gz
#   Parsing ustacks_out/2005_457_1.models.tsv.gz
#   Parsing ustacks_out/2005_459_1.models.tsv.gz
#   Parsing ustacks_out/2005_462_1.models.tsv.gz
#   Parsing ustacks_out/2005_463_1.models.tsv.gz
#   Parsing ustacks_out/2005_464_1.models.tsv.gz
#   Parsing ustacks_out/2005_465_1.models.tsv.gz
#   Parsing ustacks_out/2005_466_1.models.tsv.gz
#   Parsing ustacks_out/2009_172_1.models.tsv.gz
#   Parsing ustacks_out/2009_173_1.models.tsv.gz
#   Parsing ustacks_out/2010_114_1.models.tsv.gz
#   Parsing ustacks_out/2010_115_1.models.tsv.gz
#   Parsing ustacks_out/2010_116_1.models.tsv.gz
#   Parsing ustacks_out/2010_117_1.models.tsv.gz
#   Parsing ustacks_out/2010_118_1.models.tsv.gz
#   Parsing ustacks_out/2010_119_1.models.tsv.gz
#   Parsing ustacks_out/2010_123_1.models.tsv.gz
#   Parsing ustacks_out/2010_127_1.models.tsv.gz
#   Parsing ustacks_out/2010_184_1.models.tsv.gz
#   Parsing ustacks_out/2010_187_1.models.tsv.gz
#   Parsing ustacks_out/2010_188_1.models.tsv.gz
#   Parsing ustacks_out/2010_189_1.models.tsv.gz
#   Parsing ustacks_out/2010_211_1.models.tsv.gz
# Generating nucleotide-level summary statistics for population '2005'
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6 individual 24196; position: 74
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6 individual 29030; position: 74
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 7 individual 34327; position: 118
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 10 individual 168; position: 108
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 19 individual 4832; position: 61
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 1426; position: 63
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 24365; position: 63
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 1257; position: 63
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 180; position: 63
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 14992; position: 63
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 1426; position: 131
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 24365; position: 131
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 1257; position: 131
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 180; position: 131
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 22 individual 14992; position: 131
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 24 individual 182; position: 74
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 31 individual 18776; position: 27
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 35 individual 7093; position: 46
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 35 individual 40554; position: 46
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 35 individual 20742; position: 121
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 37 individual 22103; position: 27
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 37 individual 16000; position: 42
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 37 individual 22103; position: 49
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 38 individual 4648; position: 91
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 38 individual 11975; position: 91
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 38 individual 16152; position: 91
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 39 individual 4649; position: 50
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 39 individual 12775; position: 50
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 39 individual 11976; position: 50
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 39 individual 10928; position: 50
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 39 individual 197; position: 50
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 39 individual 5166; position: 50
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 42 individual 4197; position: 37
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 42 individual 200; position: 37
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 42 individual 8751; position: 37
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 42 individual 15879; position: 37
# Model: OOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 43 individual 27277; position: 13
# Model: OOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 43 individual 201; position: 13
# Model: OOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 43 individual 36273; position: 13
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 43 individual 3326; position: 34
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 43 individual 36548; position: 133
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 44 individual 757; position: 99
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 44 individual 202; position: 99
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 44 individual 4794; position: 133
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 44 individual 12524; position: 133
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 44 individual 7275; position: 133
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 46 individual 7511; position: 40
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 46 individual 3164; position: 40
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 46 individual 204; position: 40
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 46 individual 16239; position: 40
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 47 individual 95; position: 79
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 47 individual 30678; position: 79
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 47 individual 205; position: 79
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 47 individual 1290; position: 79
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 650; position: 9
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 28945; position: 9
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 8424; position: 9
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 208; position: 9
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 28658; position: 9
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 27434; position: 9
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 650; position: 95
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 28945; position: 95
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 8424; position: 95
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 208; position: 95
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 28658; position: 95
# Model: OOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 50 individual 27434; position: 95
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 52 individual 13816; position: 87
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 52 individual 210; position: 87
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 53 individual 1001; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 53 individual 34362; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 53 individual 14666; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 53 individual 12641; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 53 individual 211; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 60 individual 20486; position: 86
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 60 individual 1334; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 60 individual 9836; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 60 individual 2407; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 60 individual 20486; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 60 individual 5201; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 60 individual 218; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 61 individual 9944; position: 72
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 61 individual 219; position: 72
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 68 individual 21221; position: 94
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 79 individual 26112; position: 38
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 79 individual 237; position: 40
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 79 individual 237; position: 42
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 79 individual 26112; position: 42
# Model: OOOOOOOOOOOEOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 81 individual 526; position: 11
# Model: OOOOOOOOOOOEOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 81 individual 28099; position: 11
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 81 individual 6042; position: 27
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 81 individual 13248; position: 27
# Model: OOOOOOOOOOOEOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 81 individual 526; position: 27
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 81 individual 40490; position: 27
# Model: OOOOOOOOOOOEOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 81 individual 28099; position: 27
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 81 individual 40490; position: 53
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 82 individual 240; position: 74
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 86 individual 4335; position: 106
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 86 individual 7423; position: 106
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 86 individual 25035; position: 106
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 86 individual 244; position: 106
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 86 individual 4335; position: 107
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 86 individual 7423; position: 107
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 86 individual 25035; position: 107
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 86 individual 244; position: 107
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 96 individual 254; position: 123
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 97 individual 255; position: 45
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 97 individual 25104; position: 110
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 98 individual 15194; position: 37
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 98 individual 6520; position: 43
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 98 individual 17257; position: 43
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 101 individual 10507; position: 98
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 102 individual 13589; position: 40
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 102 individual 16167; position: 66
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 102 individual 260; position: 66
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 102 individual 260; position: 112
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 103 individual 7297; position: 54
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 103 individual 12086; position: 54
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 103 individual 261; position: 54
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 104 individual 15590; position: 71
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 104 individual 262; position: 71
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 105 individual 2115; position: 52
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 107 individual 2521; position: 41
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 107 individual 2521; position: 96
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 108 individual 3259; position: 78
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 108 individual 12955; position: 78
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 108 individual 26997; position: 78
# Model: OOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 109 individual 1173; position: 7
# Model: OOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 109 individual 1173; position: 93
# Model: OOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 114 individual 2420; position: 14
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 118 individual 1565; position: 79
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 118 individual 14785; position: 79
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 118 individual 276; position: 79
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 123 individual 4604; position: 49
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 123 individual 20276; position: 49
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 123 individual 7776; position: 49
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 123 individual 4604; position: 93
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 123 individual 4604; position: 107
# Model: OOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 124 individual 12149; position: 13
# Model: OOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 124 individual 5384; position: 13
# Model: OOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 124 individual 282; position: 13
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 127 individual 30759; position: 35
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 127 individual 12140; position: 35
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 127 individual 20314; position: 47
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 127 individual 20314; position: 104
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 133 individual 10890; position: 31
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 135 individual 293; position: 138
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 138 individual 296; position: 40
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 139 individual 17462; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 139 individual 26519; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 139 individual 12567; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 139 individual 297; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 141 individual 29983; position: 78
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 141 individual 17077; position: 78
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 141 individual 8207; position: 78
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 141 individual 29983; position: 100
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 141 individual 17077; position: 100
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 141 individual 299; position: 100
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 141 individual 8207; position: 100
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 6540; position: 16
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 10582; position: 16
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 20469; position: 16
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 10678; position: 16
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 20441; position: 16
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 300; position: 16
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 6540; position: 43
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 10582; position: 43
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 20469; position: 43
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 10678; position: 43
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 20441; position: 43
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 300; position: 43
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 6540; position: 87
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 142 individual 10582; position: 87
# Model: OOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# ...
# Warning: heterozygous model call at fixed nucleotide position: locus 6643 individual 4341; position: 139
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6645 individual 3909; position: 96
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6645 individual 6892; position: 96
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6647 individual 20166; position: 132
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6647 individual 1019; position: 132
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6647 individual 13745; position: 132
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6654 individual 12751; position: 46
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6654 individual 42109; position: 46
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6654 individual 12751; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6654 individual 42109; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6655 individual 30704; position: 137
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6657 individual 6876; position: 31
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6657 individual 6904; position: 31
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOUOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 14086; position: 55
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 13758; position: 55
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 2120; position: 55
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 6331; position: 55
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOUOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 14086; position: 70
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 13758; position: 70
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 2120; position: 70
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 6331; position: 70
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 10083; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 13758; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 2120; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 42345; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6658 individual 6331; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6670 individual 15055; position: 123
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6670 individual 6917; position: 123
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6678 individual 26632; position: 31
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6679 individual 13518; position: 128
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOEOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6679 individual 24411; position: 128
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOEOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6679 individual 24411; position: 132
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6681 individual 3410; position: 43
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6681 individual 3410; position: 124
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6682 individual 6929; position: 62
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEO
# Warning: heterozygous model call at fixed nucleotide position: locus 6683 individual 19709; position: 142
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6691 individual 5482; position: 105
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6693 individual 3569; position: 131
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6693 individual 6940; position: 131
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6694 individual 6941; position: 138
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOEE
# Warning: heterozygous model call at fixed nucleotide position: locus 6695 individual 4894; position: 133
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOEE
# Warning: heterozygous model call at fixed nucleotide position: locus 6695 individual 4894; position: 142
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOEE
# Warning: heterozygous model call at fixed nucleotide position: locus 6695 individual 4894; position: 143
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOE
# Warning: heterozygous model call at fixed nucleotide position: locus 6695 individual 30920; position: 143
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6696 individual 15210; position: 98
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6696 individual 15838; position: 98
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6696 individual 6943; position: 98
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6696 individual 3673; position: 98
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6696 individual 15210; position: 114
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6696 individual 6943; position: 114
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOEEOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6696 individual 6943; position: 115
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6700 individual 6947; position: 49
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6701 individual 6948; position: 34
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6702 individual 6949; position: 64
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOE
# Warning: heterozygous model call at fixed nucleotide position: locus 6702 individual 7696; position: 143
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOE
# Warning: heterozygous model call at fixed nucleotide position: locus 6702 individual 15829; position: 143
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOE
# Warning: heterozygous model call at fixed nucleotide position: locus 6702 individual 11232; position: 143
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6705 individual 6952; position: 60
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6709 individual 8440; position: 72
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6709 individual 16606; position: 72
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6709 individual 6956; position: 72
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOEOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide position: locus 6710 individual 22913; position: 72
# Model: OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOEOEOOOOOOOOOOOOOOOO
# Warning: heterozygous model call at fixed nucleotide positio

# %% [markdown]
# ACK i just learned that what I thought was the arbitrary sample ID
